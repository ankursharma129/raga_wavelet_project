# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import scipy
import threading
import python_speech_features
from scipy.io import wavfile
import scipy.fftpack as fft
from scipy.signal import get_window
import IPython.display as ipd
import math
# %matplotlib inline
import librosa
import pickle
from os import listdir
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN, LSTM
from keras.layers import Dropout
from os.path import isfile, join
from keras.layers import Flatten, Conv1D, Input, MaxPooling1D, Conv2D, MaxPooling2D, BatchNormalization, Reshape
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from tensorflow.keras.models import Model, load_model
from keras.layers import Input
from tensorflow.keras import layers
from tensorflow.keras import layers as L
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
import pickle
import os
from os import listdir
import pywt
from pywt import dwt, wavedec
from os.path import isfile, join
import torch
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# Out:
# 2021-12-05 23:56:44.692820: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 23:56:44.692869: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
class CustomDataGen(tf.keras.utils.Sequence):
    
    def __init__(self, df,
                 batch_size, validation,
                 shuffle=True):

        self.df = df.copy()
        if validation:
            self.df = self.df[25000:]
        else:
            self.df = self.df[:25000]
        self.batch_size = batch_size
        self.shuffle = shuffle
        
        self.n = len(self.df)
    
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    
    def __get_input(self, path):
    
        objects = []
        with (open(path, "rb")) as openfile:
            while True:
                try:
                    objects.append(pickle.load(openfile))
                except EOFError:
                    break
        return objects[0]["audio"]

    
    def __get_output(self, tag):
        return lab[tag]
    
    def __get_data(self, batches):
        # Generates data containing batch_size samples

        files = batches["file"]
        tag = batches["tag"]

        X_batch = np.asarray([self.__get_input(x) for x in files])

        y_batch = np.asarray([self.__get_output(y) for y in tag])

        return X_batch, y_batch
    
    def __getitem__(self, index):
        
        batches = self.df[index * self.batch_size:(index + 1) * self.batch_size]
        X, y = self.__get_data(batches)        
        return X, y
    
    def __len__(self):
        return self.n // self.batch_size

# %%
dft = pd.read_csv('dataGensym4.csv')
dat = []
files = dft["file"]
for i in files:
    if i.split("/")[-2] not in dat:
        dat.append(i.split("/")[-2])

lab = {}

for i in range(84):
    tag = dat[i]
    y_label = np.zeros((84))
    y_label[i] = 1
    lab[tag] = y_label
    
less = 0
good = 0
window_size = 2048
hop_size =256
allLabels = []
sample_rate = 44100

def AttRNNSpeechModel(rnn_func=L.LSTM):
    inputs = Input(shape=(7, 20, 216))
    x = L.Conv2D(128, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(64, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(32, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(16, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(8, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True)
                        )(x)
    x = L.Bidirectional(rnn_func(32, return_sequences=True)
                        )(x)

    xFirst = L.Lambda(lambda q: q[:, -1])(x)
    query = L.Dense(64)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32, activation='relu')(attVector)
    x = L.Dense(16)(x)

    output = L.Dense(84, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

model = AttRNNSpeechModel()#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])
model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.00001) 
dft = shuffle(dft)
training_generator = CustomDataGen(dft, 32, False)
validation_generator = CustomDataGen(dft, 32, True)
mc = ModelCheckpoint('best_modelsym4.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)

# %%
dft = pd.read_csv('dataGensym6.csv')
dat = []
files = dft["file"]
for i in files:
    if i.split("/")[-2] not in dat:
        dat.append(i.split("/")[-2])

lab = {}

for i in range(84):
    tag = dat[i]
    y_label = np.zeros((84))
    y_label[i] = 1
    lab[tag] = y_label
    
less = 0
good = 0
window_size = 2048
hop_size =256
allLabels = []
sample_rate = 44100

def AttRNNSpeechModel(rnn_func=L.LSTM):
    inputs = Input(shape=(7, 20, 216))
    x = L.Conv2D(128, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(64, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(32, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(16, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(8, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True)
                        )(x)
    x = L.Bidirectional(rnn_func(32, return_sequences=True)
                        )(x)

    xFirst = L.Lambda(lambda q: q[:, -1])(x)
    query = L.Dense(64)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32, activation='relu')(attVector)
    x = L.Dense(16)(x)

    output = L.Dense(84, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

model = AttRNNSpeechModel()#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])
model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.00001) 
dft = shuffle(dft)
training_generator = CustomDataGen(dft, 32, False)
validation_generator = CustomDataGen(dft, 32, True)
mc = ModelCheckpoint('best_modelsym6.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
# Out:
# 2021-12-05 23:56:51.725306: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 23:56:51.725775: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 23:56:51.726216: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 23:56:51.726606: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 23:56:51.727025: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 23:56:51.727456: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 23:56:51.727855: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 23:56:51.727882: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-12-05 23:56:51.728475: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 7, 20, 216)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 7, 20, 128)   138368      ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 7, 20, 128)  512         ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 7, 20, 64)    41024       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 7, 20, 64)   256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 7, 20, 32)    10272       ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 7, 20, 32)   128         ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 7, 20, 16)    2576        ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 20, 16)   64          ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 7, 20, 8)     648         ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 20, 8)    32          ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 7, 20, 1)     41          ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 20, 1)    4           ['conv2d_5[0][0]']
#  rmalization)
#
#  squeeze_last_dim (Lambda)      (None, 7, 20)        0           ['batch_normalization_5[0][0]']
#
#  bidirectional (Bidirectional)  (None, 7, 128)       43520       ['squeeze_last_dim[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 7, 64)       41216       ['bidirectional[0][0]']
#  )
#
#  lambda (Lambda)                (None, 64)           0           ['bidirectional_1[0][0]']
#
#  dense (Dense)                  (None, 64)           4160        ['lambda[0][0]']
#
#  dot (Dot)                      (None, 7)            0           ['dense[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  attSoftmax (Softmax)           (None, 7)            0           ['dot[0][0]']
#
#  dot_1 (Dot)                    (None, 64)           0           ['attSoftmax[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dot_1[0][0]']
#
#  dense_3 (Dense)                (None, 16)           528         ['dense_2[0][0]']
#
#  output (Dense)                 (None, 84)           1428        ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 286,857
# Trainable params: 286,359
# Non-trainable params: 498
# __________________________________________________________________________________________________
# /tmp/ipykernel_196/2381408543.py:76: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
# Epoch 1/50
# 2021-12-05 23:56:59.043398: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "AuthenticAMD" model: "241" frequency: 1999 num_cores: 64 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 524288 l3_cache_size: 67108864 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 781/781 [==============================] - ETA: 0s - loss: 2.5286 - accuracy: 0.3485
# 2021-12-05 23:59:09.866125: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "AuthenticAMD" model: "241" frequency: 1999 num_cores: 64 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 524288 l3_cache_size: 67108864 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00001: val_accuracy improved from -inf to 0.55699, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 153s 187ms/step - loss: 2.5286 - accuracy: 0.3485 - val_loss: 1.5445 - val_accuracy: 0.5570
# Epoch 2/50
# 781/781 [==============================] - ETA: 0s - loss: 1.0702 - accuracy: 0.6769
# Epoch 00002: val_accuracy improved from 0.55699 to 0.71907, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 152s 193ms/step - loss: 1.0702 - accuracy: 0.6769 - val_loss: 0.8725 - val_accuracy: 0.7191
# Epoch 3/50
# 781/781 [==============================] - ETA: 0s - loss: 0.6986 - accuracy: 0.7744
# Epoch 00003: val_accuracy improved from 0.71907 to 0.77995, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 153s 194ms/step - loss: 0.6986 - accuracy: 0.7744 - val_loss: 0.6859 - val_accuracy: 0.7800
# Epoch 4/50
# 781/781 [==============================] - ETA: 0s - loss: 0.5290 - accuracy: 0.8235
# Epoch 00004: val_accuracy improved from 0.77995 to 0.80473, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 156s 197ms/step - loss: 0.5290 - accuracy: 0.8235 - val_loss: 0.5999 - val_accuracy: 0.8047
# Epoch 5/50
# 781/781 [==============================] - ETA: 0s - loss: 0.4380 - accuracy: 0.8488
# Epoch 00005: val_accuracy improved from 0.80473 to 0.83663, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 154s 195ms/step - loss: 0.4380 - accuracy: 0.8488 - val_loss: 0.4872 - val_accuracy: 0.8366
# Epoch 6/50
# 781/781 [==============================] - ETA: 0s - loss: 0.3852 - accuracy: 0.8679
# Epoch 00006: val_accuracy improved from 0.83663 to 0.86269, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 159s 202ms/step - loss: 0.3852 - accuracy: 0.8679 - val_loss: 0.4256 - val_accuracy: 0.8627
# Epoch 7/50
# 781/781 [==============================] - ETA: 0s - loss: 0.3244 - accuracy: 0.8874
# Epoch 00007: val_accuracy improved from 0.86269 to 0.87646, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 153s 194ms/step - loss: 0.3244 - accuracy: 0.8874 - val_loss: 0.3744 - val_accuracy: 0.8765
# Epoch 8/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2951 - accuracy: 0.8984
# Epoch 00008: val_accuracy did not improve from 0.87646
# 781/781 [==============================] - 164s 208ms/step - loss: 0.2951 - accuracy: 0.8984 - val_loss: 0.4038 - val_accuracy: 0.8674
# Epoch 9/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.9067
# Epoch 00009: val_accuracy improved from 0.87646 to 0.87808, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 156s 197ms/step - loss: 0.2714 - accuracy: 0.9067 - val_loss: 0.3809 - val_accuracy: 0.8781
# Epoch 10/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9151
# Epoch 00010: val_accuracy improved from 0.87808 to 0.89913, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 161s 204ms/step - loss: 0.2428 - accuracy: 0.9151 - val_loss: 0.3125 - val_accuracy: 0.8991
# Epoch 11/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2269 - accuracy: 0.9220
# Epoch 00011: val_accuracy did not improve from 0.89913
# 781/781 [==============================] - 154s 195ms/step - loss: 0.2269 - accuracy: 0.9220 - val_loss: 0.3044 - val_accuracy: 0.8982
# Epoch 12/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1995 - accuracy: 0.9298
# Epoch 00012: val_accuracy improved from 0.89913 to 0.90544, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 155s 197ms/step - loss: 0.1995 - accuracy: 0.9298 - val_loss: 0.2845 - val_accuracy: 0.9054
# Epoch 13/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.9334
# Epoch 00013: val_accuracy improved from 0.90544 to 0.90560, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 159s 201ms/step - loss: 0.1900 - accuracy: 0.9334 - val_loss: 0.2841 - val_accuracy: 0.9056
# Epoch 14/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1709 - accuracy: 0.9398
# Epoch 00014: val_accuracy improved from 0.90560 to 0.91046, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 153s 194ms/step - loss: 0.1709 - accuracy: 0.9398 - val_loss: 0.2746 - val_accuracy: 0.9105
# Epoch 15/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9409
# Epoch 00015: val_accuracy improved from 0.91046 to 0.91677, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 155s 197ms/step - loss: 0.1744 - accuracy: 0.9409 - val_loss: 0.2539 - val_accuracy: 0.9168
# Epoch 16/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1487 - accuracy: 0.9473
# Epoch 00016: val_accuracy did not improve from 0.91677
# 781/781 [==============================] - 152s 193ms/step - loss: 0.1487 - accuracy: 0.9473 - val_loss: 0.3251 - val_accuracy: 0.9001
# Epoch 17/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1471 - accuracy: 0.9496
# Epoch 00017: val_accuracy improved from 0.91677 to 0.93038, saving model to best_modelsym6.hdf5
# 781/781 [==============================] - 158s 200ms/step - loss: 0.1471 - accuracy: 0.9496 - val_loss: 0.2295 - val_accuracy: 0.9304
# Epoch 18/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9542
# Epoch 00018: val_accuracy did not improve from 0.93038
# 781/781 [==============================] - 162s 205ms/step - loss: 0.1313 - accuracy: 0.9542 - val_loss: 0.2596 - val_accuracy: 0.9231
# Epoch 19/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9556
# Epoch 00019: val_accuracy did not improve from 0.93038
# 781/781 [==============================] - 160s 202ms/step - loss: 0.1309 - accuracy: 0.9556 - val_loss: 0.2580 - val_accuracy: 0.9199
# Epoch 20/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1136 - accuracy: 0.9605
# Epoch 00020: val_accuracy did not improve from 0.93038
# 781/781 [==============================] - 161s 203ms/step - loss: 0.1136 - accuracy: 0.9605 - val_loss: 0.2422 - val_accuracy: 0.9258
# Epoch 21/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1186 - accuracy: 0.9589
# Epoch 00021: val_accuracy did not improve from 0.93038
# 781/781 [==============================] - 171s 216ms/step - loss: 0.1186 - accuracy: 0.9589 - val_loss: 0.2798 - val_accuracy: 0.9216
# Epoch 22/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9649
# Epoch 00022: val_accuracy did not improve from 0.93038
# 781/781 [==============================] - 164s 207ms/step - loss: 0.1019 - accuracy: 0.9649 - val_loss: 0.2912 - val_accuracy: 0.9118
# Epoch 23/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9664
# Epoch 00023: val_accuracy did not improve from 0.93038
# 781/781 [==============================] - 164s 208ms/step - loss: 0.0993 - accuracy: 0.9664 - val_loss: 0.2550 - val_accuracy: 0.9273
# Epoch 24/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9660
# Epoch 00024: val_accuracy did not improve from 0.93038
# 781/781 [==============================] - 163s 206ms/step - loss: 0.1016 - accuracy: 0.9660 - val_loss: 0.2718 - val_accuracy: 0.9177
# Epoch 25/50
#  83/781 [==>...........................] - ETA: 3:07 - loss: 0.0987 - accuracy: 0.9669
