# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import scipy
import threading
import python_speech_features
from scipy.io import wavfile
import scipy.fftpack as fft
from scipy.signal import get_window
import IPython.display as ipd
import math
# %matplotlib inline
import librosa
import pickle
from os import listdir
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN, LSTM
from keras.layers import Dropout
from os.path import isfile, join
from keras.layers import Flatten, Conv1D, Input, MaxPooling1D, Conv2D, MaxPooling2D, BatchNormalization, Reshape
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from tensorflow.keras.models import Model, load_model
from keras.layers import Input
from tensorflow.keras import layers
from tensorflow.keras import layers as L
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
import pickle
import os
from os import listdir
import pywt
from pywt import dwt, wavedec
from os.path import isfile, join
import torch
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# Out:
# 2021-12-08 14:37:12.989062: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-08 14:37:12.989120: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
class CustomDataGen(tf.keras.utils.Sequence):
    
    def __init__(self, df,
                 batch_size, validation,
                 shuffle=True):

        self.df = df.copy()
        if validation:
            self.df = self.df[25000:]
        else:
            self.df = self.df[:25000]
        self.batch_size = batch_size
        self.shuffle = shuffle
        
        self.n = len(self.df)
    
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    
    def __get_input(self, path):
    
        objects = []
        with (open(path, "rb")) as openfile:
            while True:
                try:
                    objects.append(pickle.load(openfile))
                except EOFError:
                    break
        return objects[0]["audio"]

    
    def __get_output(self, tag):
        return lab[tag]
    
    def __get_data(self, batches):
        # Generates data containing batch_size samples

        files = batches["file"]
        tag = batches["tag"]

        X_batch = np.asarray([self.__get_input(x) for x in files])

        y_batch = np.asarray([self.__get_output(y) for y in tag])

        return X_batch, y_batch
    
    def __getitem__(self, index):
        
        batches = self.df[index * self.batch_size:(index + 1) * self.batch_size]
        X, y = self.__get_data(batches)        
        return X, y
    
    def __len__(self):
        return self.n // self.batch_size

# %%
dft = pd.read_csv('dataGenbior1.5level7.csv')
dat = []
files = dft["file"]
for i in files:
    if i.split("/")[-2] not in dat:
        dat.append(i.split("/")[-2])

lab = {}

for i in range(84):
    tag = dat[i]
    y_label = np.zeros((84))
    y_label[i] = 1
    lab[tag] = y_label
    
less = 0
good = 0
window_size = 2048
hop_size =256
allLabels = []
sample_rate = 44100

def AttRNNSpeechModel(rnn_func=L.LSTM):
    inputs = Input(shape=(9, 20, 216))
    x = L.Conv2D(128, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(64, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(32, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(16, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(8, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True)
                        )(x)
    x = L.Bidirectional(rnn_func(32, return_sequences=True)
                        )(x)

    xFirst = L.Lambda(lambda q: q[:, -1])(x)
    query = L.Dense(64)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32, activation='relu')(attVector)
    x = L.Dense(16)(x)

    output = L.Dense(84, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

model = AttRNNSpeechModel()#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])
model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.00001) 
dft = shuffle(dft)
training_generator = CustomDataGen(dft, 32, False)
validation_generator = CustomDataGen(dft, 32, True)
mc = ModelCheckpoint('best_modelbior1.5level7.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
# Out:
# 2021-12-08 14:37:18.364748: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-12-08 14:37:18.364824: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:163] no NVIDIA GPU device is present: /dev/nvidia0 does not exist
# 2021-12-08 14:37:18.365476: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 9, 20, 216)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 9, 20, 128)   138368      ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 9, 20, 128)  512         ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 9, 20, 64)    41024       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 9, 20, 64)   256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 9, 20, 32)    10272       ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 9, 20, 32)   128         ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 9, 20, 16)    2576        ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 9, 20, 16)   64          ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 9, 20, 8)     648         ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 9, 20, 8)    32          ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 9, 20, 1)     41          ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 9, 20, 1)    4           ['conv2d_5[0][0]']
#  rmalization)
#
#  squeeze_last_dim (Lambda)      (None, 9, 20)        0           ['batch_normalization_5[0][0]']
#
#  bidirectional (Bidirectional)  (None, 9, 128)       43520       ['squeeze_last_dim[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 9, 64)       41216       ['bidirectional[0][0]']
#  )
#
#  lambda (Lambda)                (None, 64)           0           ['bidirectional_1[0][0]']
#
#  dense (Dense)                  (None, 64)           4160        ['lambda[0][0]']
#
#  dot (Dot)                      (None, 9)            0           ['dense[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  attSoftmax (Softmax)           (None, 9)            0           ['dot[0][0]']
#
#  dot_1 (Dot)                    (None, 64)           0           ['attSoftmax[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dot_1[0][0]']
#
#  dense_3 (Dense)                (None, 16)           528         ['dense_2[0][0]']
#
#  output (Dense)                 (None, 84)           1428        ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 286,857
# Trainable params: 286,359
# Non-trainable params: 498
# __________________________________________________________________________________________________
# /tmp/ipykernel_34031/3038018326.py:76: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
# Epoch 1/50
# 2021-12-08 14:37:26.130361: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2294 num_cores: 48 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 31457280 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 781/781 [==============================] - ETA: 0s - loss: 2.3979 - accuracy: 0.3819
# 2021-12-08 14:38:37.940677: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "111" frequency: 2294 num_cores: 48 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 262144 l3_cache_size: 31457280 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00001: val_accuracy improved from -inf to 0.62956, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 89s 103ms/step - loss: 2.3979 - accuracy: 0.3819 - val_loss: 1.2549 - val_accuracy: 0.6296
# Epoch 2/50
# 781/781 [==============================] - ETA: 0s - loss: 0.9272 - accuracy: 0.7152
# Epoch 00002: val_accuracy improved from 0.62956 to 0.76221, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 88s 111ms/step - loss: 0.9272 - accuracy: 0.7152 - val_loss: 0.7502 - val_accuracy: 0.7622
# Epoch 3/50
# 780/781 [============================>.] - ETA: 0s - loss: 0.6139 - accuracy: 0.8038
# Epoch 00003: val_accuracy improved from 0.76221 to 0.80322, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 85s 107ms/step - loss: 0.6137 - accuracy: 0.8039 - val_loss: 0.6246 - val_accuracy: 0.8032
# Epoch 4/50
# 781/781 [==============================] - ETA: 0s - loss: 0.4575 - accuracy: 0.8462
# Epoch 00004: val_accuracy improved from 0.80322 to 0.84049, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 86s 109ms/step - loss: 0.4575 - accuracy: 0.8462 - val_loss: 0.4777 - val_accuracy: 0.8405
# Epoch 5/50
# 781/781 [==============================] - ETA: 0s - loss: 0.3854 - accuracy: 0.8699
# Epoch 00005: val_accuracy improved from 0.84049 to 0.85352, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 84s 107ms/step - loss: 0.3854 - accuracy: 0.8699 - val_loss: 0.4286 - val_accuracy: 0.8535
# Epoch 6/50
# 781/781 [==============================] - ETA: 0s - loss: 0.3347 - accuracy: 0.8849
# Epoch 00006: val_accuracy improved from 0.85352 to 0.87581, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 92s 116ms/step - loss: 0.3347 - accuracy: 0.8849 - val_loss: 0.3957 - val_accuracy: 0.8758
# Epoch 7/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.9002
# Epoch 00007: val_accuracy did not improve from 0.87581
# 781/781 [==============================] - 85s 107ms/step - loss: 0.2887 - accuracy: 0.9002 - val_loss: 0.3940 - val_accuracy: 0.8703
# Epoch 8/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2694 - accuracy: 0.9069
# Epoch 00008: val_accuracy improved from 0.87581 to 0.89600, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 87s 110ms/step - loss: 0.2694 - accuracy: 0.9069 - val_loss: 0.3163 - val_accuracy: 0.8960
# Epoch 9/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9183
# Epoch 00009: val_accuracy did not improve from 0.89600
# 781/781 [==============================] - 88s 112ms/step - loss: 0.2395 - accuracy: 0.9183 - val_loss: 0.3819 - val_accuracy: 0.8761
# Epoch 10/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9210
# Epoch 00010: val_accuracy did not improve from 0.89600
# 781/781 [==============================] - 85s 107ms/step - loss: 0.2289 - accuracy: 0.9210 - val_loss: 0.3608 - val_accuracy: 0.8830
# Epoch 11/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2047 - accuracy: 0.9284
# Epoch 00011: val_accuracy improved from 0.89600 to 0.90137, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 84s 105ms/step - loss: 0.2047 - accuracy: 0.9284 - val_loss: 0.2852 - val_accuracy: 0.9014
# Epoch 12/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1854 - accuracy: 0.9350
# Epoch 00012: val_accuracy did not improve from 0.90137
# 781/781 [==============================] - 87s 109ms/step - loss: 0.1854 - accuracy: 0.9350 - val_loss: 0.3247 - val_accuracy: 0.8960
# Epoch 13/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1824 - accuracy: 0.9367
# Epoch 00013: val_accuracy improved from 0.90137 to 0.90902, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 88s 111ms/step - loss: 0.1824 - accuracy: 0.9367 - val_loss: 0.2806 - val_accuracy: 0.9090
# Epoch 14/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.9445
# Epoch 00014: val_accuracy did not improve from 0.90902
# 781/781 [==============================] - 83s 105ms/step - loss: 0.1609 - accuracy: 0.9445 - val_loss: 0.3641 - val_accuracy: 0.8898
# Epoch 15/50
# 780/781 [============================>.] - ETA: 0s - loss: 0.1576 - accuracy: 0.9438
# Epoch 00015: val_accuracy improved from 0.90902 to 0.90951, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 88s 111ms/step - loss: 0.1578 - accuracy: 0.9437 - val_loss: 0.2917 - val_accuracy: 0.9095
# Epoch 16/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9495
# Epoch 00016: val_accuracy improved from 0.90951 to 0.91878, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 88s 111ms/step - loss: 0.1468 - accuracy: 0.9495 - val_loss: 0.2684 - val_accuracy: 0.9188
# Epoch 17/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 0.9529
# Epoch 00017: val_accuracy did not improve from 0.91878
# 781/781 [==============================] - 88s 111ms/step - loss: 0.1314 - accuracy: 0.9529 - val_loss: 0.2884 - val_accuracy: 0.9108
# Epoch 18/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1282 - accuracy: 0.9559
# Epoch 00018: val_accuracy did not improve from 0.91878
# 781/781 [==============================] - 84s 105ms/step - loss: 0.1282 - accuracy: 0.9559 - val_loss: 0.3265 - val_accuracy: 0.9027
# Epoch 19/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9572
# Epoch 00019: val_accuracy did not improve from 0.91878
# 781/781 [==============================] - 90s 114ms/step - loss: 0.1260 - accuracy: 0.9572 - val_loss: 0.2937 - val_accuracy: 0.9126
# Epoch 20/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9618
# Epoch 00020: val_accuracy did not improve from 0.91878
# 781/781 [==============================] - 84s 106ms/step - loss: 0.1089 - accuracy: 0.9618 - val_loss: 0.3095 - val_accuracy: 0.9142
# Epoch 21/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1176 - accuracy: 0.9599
# Epoch 00021: val_accuracy did not improve from 0.91878
# 781/781 [==============================] - 86s 108ms/step - loss: 0.1176 - accuracy: 0.9599 - val_loss: 0.2944 - val_accuracy: 0.9146
# Epoch 22/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9652
# Epoch 00022: val_accuracy did not improve from 0.91878
# 781/781 [==============================] - 88s 111ms/step - loss: 0.0981 - accuracy: 0.9652 - val_loss: 0.3099 - val_accuracy: 0.9124
# Epoch 23/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0952 - accuracy: 0.9679
# Epoch 00023: val_accuracy did not improve from 0.91878
# 781/781 [==============================] - 85s 107ms/step - loss: 0.0952 - accuracy: 0.9679 - val_loss: 0.2722 - val_accuracy: 0.9175
# Epoch 24/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0934 - accuracy: 0.9673
# Epoch 00024: val_accuracy improved from 0.91878 to 0.92969, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 85s 107ms/step - loss: 0.0934 - accuracy: 0.9673 - val_loss: 0.2597 - val_accuracy: 0.9297
# Epoch 25/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9692
# Epoch 00025: val_accuracy did not improve from 0.92969
# 781/781 [==============================] - 84s 105ms/step - loss: 0.0900 - accuracy: 0.9692 - val_loss: 0.2923 - val_accuracy: 0.9180
# Epoch 26/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9685
# Epoch 00026: val_accuracy did not improve from 0.92969
# 781/781 [==============================] - 92s 116ms/step - loss: 0.0891 - accuracy: 0.9685 - val_loss: 0.2815 - val_accuracy: 0.9233
# Epoch 27/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9712
# Epoch 00027: val_accuracy improved from 0.92969 to 0.93180, saving model to best_modelbior1.5level7.hdf5
# 781/781 [==============================] - 84s 105ms/step - loss: 0.0824 - accuracy: 0.9712 - val_loss: 0.2408 - val_accuracy: 0.9318
# Epoch 28/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0829 - accuracy: 0.9726
# Epoch 00028: val_accuracy did not improve from 0.93180
# 781/781 [==============================] - 83s 104ms/step - loss: 0.0829 - accuracy: 0.9726 - val_loss: 0.3007 - val_accuracy: 0.9199
# Epoch 29/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0778 - accuracy: 0.9731
# Epoch 00029: val_accuracy did not improve from 0.93180
# 781/781 [==============================] - 85s 106ms/step - loss: 0.0778 - accuracy: 0.9731 - val_loss: 0.2687 - val_accuracy: 0.9294
# Epoch 30/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9774
# Epoch 00030: val_accuracy did not improve from 0.93180
# 781/781 [==============================] - 88s 111ms/step - loss: 0.0639 - accuracy: 0.9774 - val_loss: 0.3215 - val_accuracy: 0.9175
# Epoch 31/50
# 780/781 [============================>.] - ETA: 0s - loss: 0.0707 - accuracy: 0.9751
# Epoch 00031: val_accuracy did not improve from 0.93180
# 781/781 [==============================] - 84s 106ms/step - loss: 0.0706 - accuracy: 0.9752 - val_loss: 0.2698 - val_accuracy: 0.9271
# Epoch 32/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0635 - accuracy: 0.9793
# Epoch 00032: val_accuracy did not improve from 0.93180
# 781/781 [==============================] - 83s 104ms/step - loss: 0.0635 - accuracy: 0.9793 - val_loss: 0.3094 - val_accuracy: 0.9159
# Epoch 33/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9792
# Epoch 00033: val_accuracy did not improve from 0.93180
# 781/781 [==============================] - 90s 113ms/step - loss: 0.0613 - accuracy: 0.9792 - val_loss: 0.3014 - val_accuracy: 0.9263
# Epoch 34/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0670 - accuracy: 0.9776
# Epoch 00034: val_accuracy did not improve from 0.93180
# 781/781 [==============================] - 84s 106ms/step - loss: 0.0670 - accuracy: 0.9776 - val_loss: 0.2889 - val_accuracy: 0.9277
# Epoch 35/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9783
# Epoch 00035: val_accuracy did not improve from 0.93180
# 781/781 [==============================] - 89s 111ms/step - loss: 0.0621 - accuracy: 0.9783 - val_loss: 0.2878 - val_accuracy: 0.9271
# Epoch 36/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9852
# Epoch 00036: val_accuracy did not improve from 0.93180
# 781/781 [==============================] - 89s 112ms/step - loss: 0.0448 - accuracy: 0.9852 - val_loss: 0.2890 - val_accuracy: 0.9310
# Epoch 37/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0699 - accuracy: 0.9768
# Epoch 00037: val_accuracy did not improve from 0.93180
# 781/781 [==============================] - 87s 110ms/step - loss: 0.0699 - accuracy: 0.9768 - val_loss: 0.3139 - val_accuracy: 0.9255
# Epoch 00037: early stopping

# %%
dft = pd.read_csv('dataGendb12.csv')
dat = []
files = dft["file"]
for i in files:
    if i.split("/")[-2] not in dat:
        dat.append(i.split("/")[-2])

lab = {}

for i in range(84):
    tag = dat[i]
    y_label = np.zeros((84))
    y_label[i] = 1
    lab[tag] = y_label
    
less = 0
good = 0
window_size = 2048
hop_size =256
allLabels = []
sample_rate = 44100

def AttRNNSpeechModel(rnn_func=L.LSTM):
    inputs = Input(shape=(7, 20, 216))
    x = L.Conv2D(128, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(64, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(32, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(16, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(8, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True)
                        )(x)
    x = L.Bidirectional(rnn_func(32, return_sequences=True)
                        )(x)

    xFirst = L.Lambda(lambda q: q[:, -1])(x)
    query = L.Dense(64)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32, activation='relu')(attVector)
    x = L.Dense(16)(x)

    output = L.Dense(84, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

model = AttRNNSpeechModel()#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])
model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.00001) 
dft = shuffle(dft)
training_generator = CustomDataGen(dft, 32, False)
validation_generator = CustomDataGen(dft, 32, True)
mc = ModelCheckpoint('best_modeldb12.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
