# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import scipy
import threading
import python_speech_features
from scipy.io import wavfile
import scipy.fftpack as fft
from scipy.signal import get_window
import IPython.display as ipd
import math
# %matplotlib inline
import librosa
import pickle
from os import listdir
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN, LSTM
from keras.layers import Dropout
from os.path import isfile, join
from keras.layers import Flatten, Conv1D, Input, MaxPooling1D, Conv2D, MaxPooling2D, BatchNormalization, Reshape
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from tensorflow.keras.models import Model, load_model
from keras.layers import Input
from tensorflow.keras import layers
from tensorflow.keras import layers as L
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
import pickle
import os
from os import listdir
import pywt
from pywt import dwt, wavedec
from os.path import isfile, join
import torch
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %%
class CustomDataGen(tf.keras.utils.Sequence):
    
    def __init__(self, df,
                 batch_size, validation,
                 shuffle=True):

        self.df = df.copy()
        if validation:
            self.df = self.df[25000:]
        else:
            self.df = self.df[:25000]
        self.batch_size = batch_size
        self.shuffle = shuffle
        
        self.n = len(self.df)
    
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    
    def __get_input(self, path):
    
        objects = []
        with (open(path, "rb")) as openfile:
            while True:
                try:
                    objects.append(pickle.load(openfile))
                except EOFError:
                    break
        return objects[0]["audio"]

    
    def __get_output(self, tag):
        return lab[tag]
    
    def __get_data(self, batches):
        # Generates data containing batch_size samples

        files = batches["file"]
        tag = batches["tag"]

        X_batch = np.asarray([self.__get_input(x) for x in files])

        y_batch = np.asarray([self.__get_output(y) for y in tag])

        return X_batch, y_batch
    
    def __getitem__(self, index):
        
        batches = self.df[index * self.batch_size:(index + 1) * self.batch_size]
        X, y = self.__get_data(batches)        
        return X, y
    
    def __len__(self):
        return self.n // self.batch_size

# %%
dft = pd.read_csv('dataGenbior1.1.csv')
dat = []
files = dft["file"]
for i in files:
    if i.split("/")[-2] not in dat:
        dat.append(i.split("/")[-2])

lab = {}

for i in range(84):
    tag = dat[i]
    y_label = np.zeros((84))
    y_label[i] = 1
    lab[tag] = y_label
    
less = 0
good = 0
window_size = 2048
hop_size =256
allLabels = []
sample_rate = 44100

def AttRNNSpeechModel(rnn_func=L.LSTM):
    inputs = Input(shape=(7, 20, 216))
    x = L.Conv2D(128, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(64, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(32, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(16, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(8, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True)
                        )(x)
    x = L.Bidirectional(rnn_func(32, return_sequences=True)
                        )(x)

    xFirst = L.Lambda(lambda q: q[:, -1])(x)
    query = L.Dense(64)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32, activation='relu')(attVector)
    x = L.Dense(16)(x)

    output = L.Dense(84, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

model = AttRNNSpeechModel()#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])
model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.00001) 
dft = shuffle(dft)
training_generator = CustomDataGen(dft, 32, False)
validation_generator = CustomDataGen(dft, 32, True)
mc = ModelCheckpoint('best_modelbior1.1.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)

# %%
dft = pd.read_csv('dataGenbior1.5.csv')
dat = []
files = dft["file"]
for i in files:
    if i.split("/")[-2] not in dat:
        dat.append(i.split("/")[-2])

lab = {}

for i in range(84):
    tag = dat[i]
    y_label = np.zeros((84))
    y_label[i] = 1
    lab[tag] = y_label
    
less = 0
good = 0
window_size = 2048
hop_size =256
allLabels = []
sample_rate = 44100

def AttRNNSpeechModel(rnn_func=L.LSTM):
    inputs = Input(shape=(7, 20, 216))
    x = L.Conv2D(128, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(64, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(32, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(16, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(8, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True)
                        )(x)
    x = L.Bidirectional(rnn_func(32, return_sequences=True)
                        )(x)

    xFirst = L.Lambda(lambda q: q[:, -1])(x)
    query = L.Dense(64)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32, activation='relu')(attVector)
    x = L.Dense(16)(x)

    output = L.Dense(84, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

model = AttRNNSpeechModel()#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])
model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.00001) 
dft = shuffle(dft)
training_generator = CustomDataGen(dft, 32, False)
validation_generator = CustomDataGen(dft, 32, True)
mc = ModelCheckpoint('best_modelbior1.5.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
# Out:
# 2021-12-04 20:52:24.677524: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 20:52:24.677886: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 20:52:24.678217: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 20:52:24.678503: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 20:52:24.678803: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 20:52:24.679148: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 20:52:24.679436: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 20:52:24.679451: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-12-04 20:52:24.679754: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 7, 20, 216)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 7, 20, 128)   138368      ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 7, 20, 128)  512         ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 7, 20, 64)    41024       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 7, 20, 64)   256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 7, 20, 32)    10272       ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 7, 20, 32)   128         ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 7, 20, 16)    2576        ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 20, 16)   64          ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 7, 20, 8)     648         ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 20, 8)    32          ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 7, 20, 1)     41          ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 20, 1)    4           ['conv2d_5[0][0]']
#  rmalization)
#
#  squeeze_last_dim (Lambda)      (None, 7, 20)        0           ['batch_normalization_5[0][0]']
#
#  bidirectional (Bidirectional)  (None, 7, 128)       43520       ['squeeze_last_dim[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 7, 64)       41216       ['bidirectional[0][0]']
#  )
#
#  lambda (Lambda)                (None, 64)           0           ['bidirectional_1[0][0]']
#
#  dense (Dense)                  (None, 64)           4160        ['lambda[0][0]']
#
#  dot (Dot)                      (None, 7)            0           ['dense[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  attSoftmax (Softmax)           (None, 7)            0           ['dot[0][0]']
#
#  dot_1 (Dot)                    (None, 64)           0           ['attSoftmax[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dot_1[0][0]']
#
#  dense_3 (Dense)                (None, 16)           528         ['dense_2[0][0]']
#
#  output (Dense)                 (None, 84)           1428        ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 286,857
# Trainable params: 286,359
# Non-trainable params: 498
# __________________________________________________________________________________________________
# Epoch 1/50
# /tmp/ipykernel_266882/1641349711.py:76: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
# 2021-12-04 20:52:29.881012: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2100 num_cores: 64 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 23068672 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 781/781 [==============================] - ETA: 0s - loss: 2.5086 - accuracy: 0.3442
# 2021-12-04 20:53:58.783229: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2100 num_cores: 64 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 23068672 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00001: val_accuracy improved from -inf to 0.43685, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 105s 127ms/step - loss: 2.5086 - accuracy: 0.3442 - val_loss: 1.9987 - val_accuracy: 0.4369
# Epoch 2/50
# 781/781 [==============================] - ETA: 0s - loss: 1.2759 - accuracy: 0.6188 ETA: 0s - loss: 1.2773 - accuracy
# Epoch 00002: val_accuracy improved from 0.43685 to 0.70337, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 106s 134ms/step - loss: 1.2759 - accuracy: 0.6188 - val_loss: 0.9502 - val_accuracy: 0.7034
# Epoch 3/50
# 781/781 [==============================] - ETA: 0s - loss: 0.8528 - accuracy: 0.7306
# Epoch 00003: val_accuracy improved from 0.70337 to 0.76150, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 106s 134ms/step - loss: 0.8528 - accuracy: 0.7306 - val_loss: 0.7394 - val_accuracy: 0.7615
# Epoch 4/50
# 781/781 [==============================] - ETA: 0s - loss: 0.6387 - accuracy: 0.7907
# Epoch 00004: val_accuracy improved from 0.76150 to 0.81768, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 111s 140ms/step - loss: 0.6387 - accuracy: 0.7907 - val_loss: 0.5531 - val_accuracy: 0.8177
# Epoch 5/50
# 781/781 [==============================] - ETA: 0s - loss: 0.5086 - accuracy: 0.8306
# Epoch 00005: val_accuracy improved from 0.81768 to 0.83161, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 110s 139ms/step - loss: 0.5086 - accuracy: 0.8306 - val_loss: 0.5094 - val_accuracy: 0.8316
# Epoch 6/50
# 781/781 [==============================] - ETA: 0s - loss: 0.4077 - accuracy: 0.8614
# Epoch 00006: val_accuracy improved from 0.83161 to 0.85703, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 107s 135ms/step - loss: 0.4077 - accuracy: 0.8614 - val_loss: 0.4230 - val_accuracy: 0.8570
# Epoch 7/50
# 781/781 [==============================] - ETA: 0s - loss: 0.3595 - accuracy: 0.8760
# Epoch 00007: val_accuracy improved from 0.85703 to 0.86577, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 102s 128ms/step - loss: 0.3595 - accuracy: 0.8760 - val_loss: 0.3998 - val_accuracy: 0.8658
# Epoch 8/50
# 781/781 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8920
# Epoch 00008: val_accuracy improved from 0.86577 to 0.88115, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 111s 141ms/step - loss: 0.3155 - accuracy: 0.8920 - val_loss: 0.3421 - val_accuracy: 0.8812
# Epoch 9/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2839 - accuracy: 0.9003
# Epoch 00009: val_accuracy did not improve from 0.88115
# 781/781 [==============================] - 108s 137ms/step - loss: 0.2839 - accuracy: 0.9003 - val_loss: 0.3714 - val_accuracy: 0.8776
# Epoch 10/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.9052
# Epoch 00010: val_accuracy improved from 0.88115 to 0.90026, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 107s 135ms/step - loss: 0.2667 - accuracy: 0.9052 - val_loss: 0.3003 - val_accuracy: 0.9003
# Epoch 11/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.9163
# Epoch 00011: val_accuracy did not improve from 0.90026
# 781/781 [==============================] - 113s 143ms/step - loss: 0.2385 - accuracy: 0.9163 - val_loss: 0.3201 - val_accuracy: 0.8894
# Epoch 12/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2179 - accuracy: 0.9229
# Epoch 00012: val_accuracy did not improve from 0.90026
# 781/781 [==============================] - 105s 132ms/step - loss: 0.2179 - accuracy: 0.9229 - val_loss: 0.3016 - val_accuracy: 0.9003
# Epoch 13/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2039 - accuracy: 0.9279
# Epoch 00013: val_accuracy did not improve from 0.90026
# 781/781 [==============================] - 106s 134ms/step - loss: 0.2039 - accuracy: 0.9279 - val_loss: 0.3069 - val_accuracy: 0.8972
# Epoch 14/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9323
# Epoch 00014: val_accuracy improved from 0.90026 to 0.91273, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 107s 135ms/step - loss: 0.1892 - accuracy: 0.9323 - val_loss: 0.2638 - val_accuracy: 0.9127
# Epoch 15/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9358
# Epoch 00015: val_accuracy did not improve from 0.91273
# 781/781 [==============================] - 108s 136ms/step - loss: 0.1845 - accuracy: 0.9358 - val_loss: 0.2807 - val_accuracy: 0.9122
# Epoch 16/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9413
# Epoch 00016: val_accuracy did not improve from 0.91273
# 781/781 [==============================] - 109s 137ms/step - loss: 0.1681 - accuracy: 0.9413 - val_loss: 0.2632 - val_accuracy: 0.9119
# Epoch 17/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9461
# Epoch 00017: val_accuracy improved from 0.91273 to 0.91726, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 108s 136ms/step - loss: 0.1524 - accuracy: 0.9461 - val_loss: 0.2540 - val_accuracy: 0.9173
# Epoch 18/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9489
# Epoch 00018: val_accuracy did not improve from 0.91726
# 781/781 [==============================] - 113s 142ms/step - loss: 0.1470 - accuracy: 0.9489 - val_loss: 0.2682 - val_accuracy: 0.9168
# Epoch 19/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9500
# Epoch 00019: val_accuracy did not improve from 0.91726
# 781/781 [==============================] - 113s 143ms/step - loss: 0.1400 - accuracy: 0.9500 - val_loss: 0.2914 - val_accuracy: 0.9114
# Epoch 20/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1342 - accuracy: 0.9529 ETA: 1s - loss: 0
# Epoch 00020: val_accuracy improved from 0.91726 to 0.92050, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 115s 144ms/step - loss: 0.1342 - accuracy: 0.9529 - val_loss: 0.2538 - val_accuracy: 0.9205
# Epoch 21/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1268 - accuracy: 0.9557
# Epoch 00021: val_accuracy did not improve from 0.92050
# 781/781 [==============================] - 107s 134ms/step - loss: 0.1268 - accuracy: 0.9557 - val_loss: 0.2566 - val_accuracy: 0.9187
# Epoch 22/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9580
# Epoch 00022: val_accuracy did not improve from 0.92050
# 781/781 [==============================] - 107s 135ms/step - loss: 0.1221 - accuracy: 0.9580 - val_loss: 0.2764 - val_accuracy: 0.9155
# Epoch 23/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1152 - accuracy: 0.9602
# Epoch 00023: val_accuracy improved from 0.92050 to 0.92082, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 110s 138ms/step - loss: 0.1152 - accuracy: 0.9602 - val_loss: 0.2538 - val_accuracy: 0.9208
# Epoch 24/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9629
# Epoch 00024: val_accuracy improved from 0.92082 to 0.92131, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 112s 141ms/step - loss: 0.1046 - accuracy: 0.9629 - val_loss: 0.2582 - val_accuracy: 0.9213
# Epoch 25/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1135 - accuracy: 0.9589
# Epoch 00025: val_accuracy did not improve from 0.92131
# 781/781 [==============================] - 113s 142ms/step - loss: 0.1135 - accuracy: 0.9589 - val_loss: 0.2673 - val_accuracy: 0.9203
# Epoch 26/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0973 - accuracy: 0.9676
# Epoch 00026: val_accuracy did not improve from 0.92131
# 781/781 [==============================] - 117s 148ms/step - loss: 0.0973 - accuracy: 0.9676 - val_loss: 0.2880 - val_accuracy: 0.9169
# Epoch 27/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9662
# Epoch 00027: val_accuracy did not improve from 0.92131
# 781/781 [==============================] - 113s 143ms/step - loss: 0.0968 - accuracy: 0.9662 - val_loss: 0.2711 - val_accuracy: 0.9211
# Epoch 28/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9684
# Epoch 00028: val_accuracy improved from 0.92131 to 0.92390, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 106s 133ms/step - loss: 0.0926 - accuracy: 0.9684 - val_loss: 0.2521 - val_accuracy: 0.9239
# Epoch 29/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0731 - accuracy: 0.9744
# Epoch 00029: val_accuracy did not improve from 0.92390
# 781/781 [==============================] - 108s 136ms/step - loss: 0.0731 - accuracy: 0.9744 - val_loss: 0.2694 - val_accuracy: 0.9215
# Epoch 30/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0867 - accuracy: 0.9702
# Epoch 00030: val_accuracy improved from 0.92390 to 0.92746, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 116s 146ms/step - loss: 0.0867 - accuracy: 0.9702 - val_loss: 0.2629 - val_accuracy: 0.9275
# Epoch 31/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9699
# Epoch 00031: val_accuracy improved from 0.92746 to 0.92924, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 108s 136ms/step - loss: 0.0855 - accuracy: 0.9699 - val_loss: 0.2384 - val_accuracy: 0.9292
# Epoch 32/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0735 - accuracy: 0.9758
# Epoch 00032: val_accuracy did not improve from 0.92924
# 781/781 [==============================] - 110s 138ms/step - loss: 0.0735 - accuracy: 0.9758 - val_loss: 0.2913 - val_accuracy: 0.9252
# Epoch 33/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9721
# Epoch 00033: val_accuracy did not improve from 0.92924
# 781/781 [==============================] - 108s 135ms/step - loss: 0.0786 - accuracy: 0.9721 - val_loss: 0.2593 - val_accuracy: 0.9283
# Epoch 34/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9758
# Epoch 00034: val_accuracy improved from 0.92924 to 0.92940, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 109s 137ms/step - loss: 0.0690 - accuracy: 0.9758 - val_loss: 0.2682 - val_accuracy: 0.9294
# Epoch 35/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9770
# Epoch 00035: val_accuracy did not improve from 0.92940
# 781/781 [==============================] - 110s 138ms/step - loss: 0.0674 - accuracy: 0.9770 - val_loss: 0.3153 - val_accuracy: 0.9195
# Epoch 36/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9782
# Epoch 00036: val_accuracy did not improve from 0.92940
# 781/781 [==============================] - 112s 140ms/step - loss: 0.0657 - accuracy: 0.9782 - val_loss: 0.2967 - val_accuracy: 0.9221
# Epoch 37/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0644 - accuracy: 0.9781
# Epoch 00037: val_accuracy improved from 0.92940 to 0.93475, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 111s 139ms/step - loss: 0.0644 - accuracy: 0.9781 - val_loss: 0.2448 - val_accuracy: 0.9347
# Epoch 38/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9832
# Epoch 00038: val_accuracy did not improve from 0.93475
# 781/781 [==============================] - 109s 138ms/step - loss: 0.0507 - accuracy: 0.9832 - val_loss: 0.2527 - val_accuracy: 0.9325
# Epoch 39/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9778
# Epoch 00039: val_accuracy did not improve from 0.93475
# 781/781 [==============================] - 110s 137ms/step - loss: 0.0678 - accuracy: 0.9778 - val_loss: 0.2787 - val_accuracy: 0.9268
# Epoch 40/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0582 - accuracy: 0.9810
# Epoch 00040: val_accuracy did not improve from 0.93475
# 781/781 [==============================] - 107s 135ms/step - loss: 0.0582 - accuracy: 0.9810 - val_loss: 0.2742 - val_accuracy: 0.9315
# Epoch 41/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9791
# Epoch 00041: val_accuracy improved from 0.93475 to 0.94090, saving model to best_modelbior1.5.hdf5
# 781/781 [==============================] - 108s 136ms/step - loss: 0.0621 - accuracy: 0.9791 - val_loss: 0.2251 - val_accuracy: 0.9409
# Epoch 42/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9853
# Epoch 00042: val_accuracy did not improve from 0.94090
# 781/781 [==============================] - 109s 137ms/step - loss: 0.0454 - accuracy: 0.9853 - val_loss: 0.2537 - val_accuracy: 0.9375
# Epoch 43/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9741 ETA: 1s - loss:
# Epoch 00043: val_accuracy did not improve from 0.94090
# 781/781 [==============================] - 106s 132ms/step - loss: 0.0768 - accuracy: 0.9741 - val_loss: 0.2545 - val_accuracy: 0.9331
# Epoch 44/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0638 - accuracy: 0.9798
# Epoch 00044: val_accuracy did not improve from 0.94090
# 781/781 [==============================] - 109s 137ms/step - loss: 0.0638 - accuracy: 0.9798 - val_loss: 0.2528 - val_accuracy: 0.9322
# Epoch 45/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9867
# Epoch 00045: val_accuracy did not improve from 0.94090
# 781/781 [==============================] - 110s 139ms/step - loss: 0.0404 - accuracy: 0.9867 - val_loss: 0.3417 - val_accuracy: 0.9200
# Epoch 46/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9850
# Epoch 00046: val_accuracy did not improve from 0.94090
# 781/781 [==============================] - 111s 139ms/step - loss: 0.0458 - accuracy: 0.9850 - val_loss: 0.3292 - val_accuracy: 0.9242
# Epoch 47/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9818
# Epoch 00047: val_accuracy did not improve from 0.94090
# 781/781 [==============================] - 108s 136ms/step - loss: 0.0543 - accuracy: 0.9818 - val_loss: 0.2788 - val_accuracy: 0.9309
# Epoch 48/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9851
# Epoch 00048: val_accuracy did not improve from 0.94090
# 781/781 [==============================] - 108s 136ms/step - loss: 0.0459 - accuracy: 0.9851 - val_loss: 0.2464 - val_accuracy: 0.9391
# Epoch 49/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9844
# Epoch 00049: val_accuracy did not improve from 0.94090
# 781/781 [==============================] - 112s 141ms/step - loss: 0.0504 - accuracy: 0.9844 - val_loss: 0.3175 - val_accuracy: 0.9215
# Epoch 50/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9854
# Epoch 00050: val_accuracy did not improve from 0.94090
# 781/781 [==============================] - 110s 138ms/step - loss: 0.0421 - accuracy: 0.9854 - val_loss: 0.3041 - val_accuracy: 0.9244
