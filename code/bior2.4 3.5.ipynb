# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import scipy
import threading
import python_speech_features
from scipy.io import wavfile
import scipy.fftpack as fft
from scipy.signal import get_window
import IPython.display as ipd
import math
# %matplotlib inline
import librosa
import pickle
from os import listdir
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN, LSTM
from keras.layers import Dropout
from os.path import isfile, join
from keras.layers import Flatten, Conv1D, Input, MaxPooling1D, Conv2D, MaxPooling2D, BatchNormalization, Reshape
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from tensorflow.keras.models import Model, load_model
from keras.layers import Input
from tensorflow.keras import layers
from tensorflow.keras import layers as L
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
import pickle
import os
from os import listdir
import pywt
from pywt import dwt, wavedec
from os.path import isfile, join
import torch
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# Out:
# 2021-12-04 18:05:38.318026: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 18:05:38.318058: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
class CustomDataGen(tf.keras.utils.Sequence):
    
    def __init__(self, df,
                 batch_size, validation,
                 shuffle=True):

        self.df = df.copy()
        if validation:
            self.df = self.df[25000:]
        else:
            self.df = self.df[:25000]
        self.batch_size = batch_size
        self.shuffle = shuffle
        
        self.n = len(self.df)
    
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    
    def __get_input(self, path):
    
        objects = []
        with (open(path, "rb")) as openfile:
            while True:
                try:
                    objects.append(pickle.load(openfile))
                except EOFError:
                    break
        return objects[0]["audio"]

    
    def __get_output(self, tag):
        return lab[tag]
    
    def __get_data(self, batches):
        # Generates data containing batch_size samples

        files = batches["file"]
        tag = batches["tag"]

        X_batch = np.asarray([self.__get_input(x) for x in files])

        y_batch = np.asarray([self.__get_output(y) for y in tag])

        return X_batch, y_batch
    
    def __getitem__(self, index):
        
        batches = self.df[index * self.batch_size:(index + 1) * self.batch_size]
        X, y = self.__get_data(batches)        
        return X, y
    
    def __len__(self):
        return self.n // self.batch_size

# %%
dft = pd.read_csv('dataGenbior3.5.csv')
dat = []
files = dft["file"]
for i in files:
    if i.split("/")[-2] not in dat:
        dat.append(i.split("/")[-2])

lab = {}

for i in range(84):
    tag = dat[i]
    y_label = np.zeros((84))
    y_label[i] = 1
    lab[tag] = y_label
    
less = 0
good = 0
window_size = 2048
hop_size =256
allLabels = []
sample_rate = 44100

def AttRNNSpeechModel(rnn_func=L.LSTM):
    inputs = Input(shape=(7, 20, 216))
    x = L.Conv2D(128, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(64, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(32, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(16, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(8, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True)
                        )(x)
    x = L.Bidirectional(rnn_func(32, return_sequences=True)
                        )(x)

    xFirst = L.Lambda(lambda q: q[:, -1])(x)
    query = L.Dense(64)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32, activation='relu')(attVector)
    x = L.Dense(16)(x)

    output = L.Dense(84, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

model = AttRNNSpeechModel()#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])
model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.00001) 
dft = shuffle(dft)
training_generator = CustomDataGen(dft, 32, False)
validation_generator = CustomDataGen(dft, 32, True)
mc = ModelCheckpoint('best_modelbior2.4.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)

# %%
dft = pd.read_csv('dataGenbior3.5.csv')
dat = []
files = dft["file"]
for i in files:
    if i.split("/")[-2] not in dat:
        dat.append(i.split("/")[-2])

lab = {}

for i in range(84):
    tag = dat[i]
    y_label = np.zeros((84))
    y_label[i] = 1
    lab[tag] = y_label
    
less = 0
good = 0
window_size = 2048
hop_size =256
allLabels = []
sample_rate = 44100

def AttRNNSpeechModel(rnn_func=L.LSTM):
    inputs = Input(shape=(7, 20, 216))
    x = L.Conv2D(128, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(64, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(32, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(16, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(8, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True)
                        )(x)
    x = L.Bidirectional(rnn_func(32, return_sequences=True)
                        )(x)

    xFirst = L.Lambda(lambda q: q[:, -1])(x)
    query = L.Dense(64)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32, activation='relu')(attVector)
    x = L.Dense(16)(x)

    output = L.Dense(84, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

model = AttRNNSpeechModel()#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])
model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.00001) 
dft = shuffle(dft)
training_generator = CustomDataGen(dft, 32, False)
validation_generator = CustomDataGen(dft, 32, True)
mc = ModelCheckpoint('best_modelbior3.5.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
# Out:
# 2021-12-04 18:05:42.936846: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 18:05:42.936923: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 18:05:42.937019: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 18:05:42.937072: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 18:05:42.937126: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 18:05:42.937186: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 18:05:42.937241: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-04 18:05:42.937255: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-12-04 18:05:42.937568: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 7, 20, 216)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 7, 20, 128)   138368      ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 7, 20, 128)  512         ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 7, 20, 64)    41024       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 7, 20, 64)   256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 7, 20, 32)    10272       ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 7, 20, 32)   128         ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 7, 20, 16)    2576        ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 20, 16)   64          ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 7, 20, 8)     648         ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 20, 8)    32          ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 7, 20, 1)     41          ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 20, 1)    4           ['conv2d_5[0][0]']
#  rmalization)
#
#  squeeze_last_dim (Lambda)      (None, 7, 20)        0           ['batch_normalization_5[0][0]']
#
#  bidirectional (Bidirectional)  (None, 7, 128)       43520       ['squeeze_last_dim[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 7, 64)       41216       ['bidirectional[0][0]']
#  )
#
#  lambda (Lambda)                (None, 64)           0           ['bidirectional_1[0][0]']
#
#  dense (Dense)                  (None, 64)           4160        ['lambda[0][0]']
#
#  dot (Dot)                      (None, 7)            0           ['dense[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  attSoftmax (Softmax)           (None, 7)            0           ['dot[0][0]']
#
#  dot_1 (Dot)                    (None, 64)           0           ['attSoftmax[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dot_1[0][0]']
#
#  dense_3 (Dense)                (None, 16)           528         ['dense_2[0][0]']
#
#  output (Dense)                 (None, 84)           1428        ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 286,857
# Trainable params: 286,359
# Non-trainable params: 498
# __________________________________________________________________________________________________
# Epoch 1/50
# /tmp/ipykernel_256467/1108998164.py:76: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
# 2021-12-04 18:05:48.227935: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2100 num_cores: 64 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 23068672 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 781/781 [==============================] - ETA: 0s - loss: 2.5963 - accuracy: 0.3341
# 2021-12-04 18:07:17.556908: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2100 num_cores: 64 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 23068672 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00001: val_accuracy improved from -inf to 0.52931, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 105s 127ms/step - loss: 2.5963 - accuracy: 0.3341 - val_loss: 1.7076 - val_accuracy: 0.5293
# Epoch 2/50
# 781/781 [==============================] - ETA: 0s - loss: 1.1805 - accuracy: 0.6530
# Epoch 00002: val_accuracy improved from 0.52931 to 0.72523, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 105s 133ms/step - loss: 1.1805 - accuracy: 0.6530 - val_loss: 0.9181 - val_accuracy: 0.7252
# Epoch 3/50
# 781/781 [==============================] - ETA: 0s - loss: 0.7449 - accuracy: 0.7654
# Epoch 00003: val_accuracy improved from 0.72523 to 0.77413, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 110s 139ms/step - loss: 0.7449 - accuracy: 0.7654 - val_loss: 0.6918 - val_accuracy: 0.7741
# Epoch 4/50
# 781/781 [==============================] - ETA: 0s - loss: 0.5441 - accuracy: 0.8205
# Epoch 00004: val_accuracy improved from 0.77413 to 0.80635, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 105s 132ms/step - loss: 0.5441 - accuracy: 0.8205 - val_loss: 0.5890 - val_accuracy: 0.8063
# Epoch 5/50
# 781/781 [==============================] - ETA: 0s - loss: 0.4402 - accuracy: 0.8514
# Epoch 00005: val_accuracy improved from 0.80635 to 0.82885, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 107s 135ms/step - loss: 0.4402 - accuracy: 0.8514 - val_loss: 0.5222 - val_accuracy: 0.8289
# Epoch 6/50
# 781/781 [==============================] - ETA: 0s - loss: 0.3788 - accuracy: 0.8698
# Epoch 00006: val_accuracy improved from 0.82885 to 0.84521, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 108s 136ms/step - loss: 0.3788 - accuracy: 0.8698 - val_loss: 0.4777 - val_accuracy: 0.8452
# Epoch 7/50
# 781/781 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.8860
# Epoch 00007: val_accuracy improved from 0.84521 to 0.86448, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 114s 144ms/step - loss: 0.3300 - accuracy: 0.8860 - val_loss: 0.4065 - val_accuracy: 0.8645
# Epoch 8/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2952 - accuracy: 0.8998
# Epoch 00008: val_accuracy improved from 0.86448 to 0.87646, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 118s 149ms/step - loss: 0.2952 - accuracy: 0.8998 - val_loss: 0.3833 - val_accuracy: 0.8765
# Epoch 9/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2608 - accuracy: 0.9095
# Epoch 00009: val_accuracy improved from 0.87646 to 0.88148, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 121s 153ms/step - loss: 0.2608 - accuracy: 0.9095 - val_loss: 0.3795 - val_accuracy: 0.8815
# Epoch 10/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9153
# Epoch 00010: val_accuracy improved from 0.88148 to 0.88342, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 104s 132ms/step - loss: 0.2395 - accuracy: 0.9153 - val_loss: 0.3574 - val_accuracy: 0.8834
# Epoch 11/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9222
# Epoch 00011: val_accuracy improved from 0.88342 to 0.88844, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 108s 136ms/step - loss: 0.2210 - accuracy: 0.9222 - val_loss: 0.3394 - val_accuracy: 0.8884
# Epoch 12/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2013 - accuracy: 0.9293
# Epoch 00012: val_accuracy did not improve from 0.88844
# 781/781 [==============================] - 112s 141ms/step - loss: 0.2013 - accuracy: 0.9293 - val_loss: 0.3975 - val_accuracy: 0.8813
# Epoch 13/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1831 - accuracy: 0.9353
# Epoch 00013: val_accuracy did not improve from 0.88844
# 781/781 [==============================] - 108s 137ms/step - loss: 0.1831 - accuracy: 0.9353 - val_loss: 0.4368 - val_accuracy: 0.8687
# Epoch 14/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1776 - accuracy: 0.9375
# Epoch 00014: val_accuracy improved from 0.88844 to 0.91078, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 111s 140ms/step - loss: 0.1776 - accuracy: 0.9375 - val_loss: 0.2930 - val_accuracy: 0.9108
# Epoch 15/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1636 - accuracy: 0.9444
# Epoch 00015: val_accuracy did not improve from 0.91078
# 781/781 [==============================] - 109s 137ms/step - loss: 0.1636 - accuracy: 0.9444 - val_loss: 0.5103 - val_accuracy: 0.8612
# Epoch 16/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9476
# Epoch 00016: val_accuracy improved from 0.91078 to 0.91111, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 109s 138ms/step - loss: 0.1490 - accuracy: 0.9476 - val_loss: 0.3009 - val_accuracy: 0.9111
# Epoch 17/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9475
# Epoch 00017: val_accuracy did not improve from 0.91111
# 781/781 [==============================] - 104s 131ms/step - loss: 0.1505 - accuracy: 0.9475 - val_loss: 0.3295 - val_accuracy: 0.9017
# Epoch 18/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9543
# Epoch 00018: val_accuracy did not improve from 0.91111
# 781/781 [==============================] - 111s 140ms/step - loss: 0.1313 - accuracy: 0.9543 - val_loss: 0.2940 - val_accuracy: 0.9100
# Epoch 19/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9557
# Epoch 00019: val_accuracy improved from 0.91111 to 0.91758, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 122s 154ms/step - loss: 0.1279 - accuracy: 0.9557 - val_loss: 0.2774 - val_accuracy: 0.9176
# Epoch 20/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1206 - accuracy: 0.9593
# Epoch 00020: val_accuracy improved from 0.91758 to 0.91920, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 106s 133ms/step - loss: 0.1206 - accuracy: 0.9593 - val_loss: 0.2772 - val_accuracy: 0.9192
# Epoch 21/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1153 - accuracy: 0.9593
# Epoch 00021: val_accuracy did not improve from 0.91920
# 781/781 [==============================] - 109s 137ms/step - loss: 0.1153 - accuracy: 0.9593 - val_loss: 0.2948 - val_accuracy: 0.9129
# Epoch 22/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9634
# Epoch 00022: val_accuracy did not improve from 0.91920
# 781/781 [==============================] - 110s 138ms/step - loss: 0.1034 - accuracy: 0.9634 - val_loss: 0.2892 - val_accuracy: 0.9168
# Epoch 23/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9651
# Epoch 00023: val_accuracy did not improve from 0.91920
# 781/781 [==============================] - 108s 136ms/step - loss: 0.1005 - accuracy: 0.9651 - val_loss: 0.2811 - val_accuracy: 0.9192
# Epoch 24/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9659
# Epoch 00024: val_accuracy improved from 0.91920 to 0.92115, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 106s 133ms/step - loss: 0.0981 - accuracy: 0.9659 - val_loss: 0.2735 - val_accuracy: 0.9211
# Epoch 25/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0855 - accuracy: 0.9699
# Epoch 00025: val_accuracy improved from 0.92115 to 0.92163, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 108s 135ms/step - loss: 0.0855 - accuracy: 0.9699 - val_loss: 0.2748 - val_accuracy: 0.9216
# Epoch 26/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0927 - accuracy: 0.9681
# Epoch 00026: val_accuracy improved from 0.92163 to 0.92196, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 109s 137ms/step - loss: 0.0927 - accuracy: 0.9681 - val_loss: 0.2793 - val_accuracy: 0.9220
# Epoch 27/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0859 - accuracy: 0.9704
# Epoch 00027: val_accuracy did not improve from 0.92196
# 781/781 [==============================] - 106s 134ms/step - loss: 0.0859 - accuracy: 0.9704 - val_loss: 0.2789 - val_accuracy: 0.9213
# Epoch 28/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9746
# Epoch 00028: val_accuracy did not improve from 0.92196
# 781/781 [==============================] - 108s 135ms/step - loss: 0.0764 - accuracy: 0.9746 - val_loss: 0.2722 - val_accuracy: 0.9220
# Epoch 29/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9740
# Epoch 00029: val_accuracy did not improve from 0.92196
# 781/781 [==============================] - 112s 141ms/step - loss: 0.0805 - accuracy: 0.9740 - val_loss: 0.3180 - val_accuracy: 0.9140
# Epoch 30/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0715 - accuracy: 0.9754
# Epoch 00030: val_accuracy improved from 0.92196 to 0.92568, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 116s 145ms/step - loss: 0.0715 - accuracy: 0.9754 - val_loss: 0.2817 - val_accuracy: 0.9257
# Epoch 31/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0763 - accuracy: 0.9735
# Epoch 00031: val_accuracy improved from 0.92568 to 0.93135, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 105s 132ms/step - loss: 0.0763 - accuracy: 0.9735 - val_loss: 0.2651 - val_accuracy: 0.9313
# Epoch 32/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0783 - accuracy: 0.9740
# Epoch 00032: val_accuracy did not improve from 0.93135
# 781/781 [==============================] - 115s 144ms/step - loss: 0.0783 - accuracy: 0.9740 - val_loss: 0.2811 - val_accuracy: 0.9247
# Epoch 33/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9813
# Epoch 00033: val_accuracy improved from 0.93135 to 0.93151, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 105s 132ms/step - loss: 0.0599 - accuracy: 0.9813 - val_loss: 0.2773 - val_accuracy: 0.9315
# Epoch 34/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9803
# Epoch 00034: val_accuracy improved from 0.93151 to 0.93248, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 109s 137ms/step - loss: 0.0587 - accuracy: 0.9803 - val_loss: 0.2787 - val_accuracy: 0.9325
# Epoch 35/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9794
# Epoch 00035: val_accuracy did not improve from 0.93248
# 781/781 [==============================] - 109s 137ms/step - loss: 0.0612 - accuracy: 0.9794 - val_loss: 0.2817 - val_accuracy: 0.9304
# Epoch 36/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9788 ETA
# Epoch 00036: val_accuracy did not improve from 0.93248
# 781/781 [==============================] - 107s 134ms/step - loss: 0.0639 - accuracy: 0.9788 - val_loss: 0.3571 - val_accuracy: 0.9199
# Epoch 37/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9819
# Epoch 00037: val_accuracy improved from 0.93248 to 0.93361, saving model to best_modelbior3.5.hdf5
# 781/781 [==============================] - 114s 143ms/step - loss: 0.0535 - accuracy: 0.9819 - val_loss: 0.2795 - val_accuracy: 0.9336
# Epoch 38/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0454 - accuracy: 0.9851
# Epoch 00038: val_accuracy did not improve from 0.93361
# 781/781 [==============================] - 115s 144ms/step - loss: 0.0454 - accuracy: 0.9851 - val_loss: 0.3179 - val_accuracy: 0.9242
# Epoch 39/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9811
# Epoch 00039: val_accuracy did not improve from 0.93361
# 781/781 [==============================] - 108s 135ms/step - loss: 0.0596 - accuracy: 0.9811 - val_loss: 0.3513 - val_accuracy: 0.9145
# Epoch 40/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9802
# Epoch 00040: val_accuracy did not improve from 0.93361
# 781/781 [==============================] - 107s 134ms/step - loss: 0.0616 - accuracy: 0.9802 - val_loss: 0.2876 - val_accuracy: 0.9313
# Epoch 41/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9830
# Epoch 00041: val_accuracy did not improve from 0.93361
# 781/781 [==============================] - 109s 137ms/step - loss: 0.0503 - accuracy: 0.9830 - val_loss: 0.2899 - val_accuracy: 0.9299
# Epoch 00041: early stopping
