# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import scipy
import threading
import python_speech_features
from scipy.io import wavfile
import scipy.fftpack as fft
from scipy.signal import get_window
import IPython.display as ipd
import math
# %matplotlib inline
import librosa
import pickle
from os import listdir
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN, LSTM
from keras.layers import Dropout
from os.path import isfile, join
from keras.layers import Flatten, Conv1D, Input, MaxPooling1D, Conv2D, MaxPooling2D, BatchNormalization, Reshape
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from tensorflow.keras.models import Model, load_model
from keras.layers import Input
from tensorflow.keras import layers
from tensorflow.keras import layers as L
from tensorflow.keras import backend as K
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend as K
from tensorflow.keras import optimizers
import pickle
import os
from os import listdir
import pywt
from pywt import dwt, wavedec
from os.path import isfile, join
import torch
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# Out:
# 2021-12-05 01:31:07.006800: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 01:31:07.006836: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
class CustomDataGen(tf.keras.utils.Sequence):
    
    def __init__(self, df,
                 batch_size, validation,
                 shuffle=True):

        self.df = df.copy()
        if validation:
            self.df = self.df[25000:]
        else:
            self.df = self.df[:25000]
        self.batch_size = batch_size
        self.shuffle = shuffle
        
        self.n = len(self.df)
    
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    
    def __get_input(self, path):
    
        objects = []
        with (open(path, "rb")) as openfile:
            while True:
                try:
                    objects.append(pickle.load(openfile))
                except EOFError:
                    break
        return objects[0]["audio"]

    
    def __get_output(self, tag):
        return lab[tag]
    
    def __get_data(self, batches):
        # Generates data containing batch_size samples

        files = batches["file"]
        tag = batches["tag"]

        X_batch = np.asarray([self.__get_input(x) for x in files])

        y_batch = np.asarray([self.__get_output(y) for y in tag])

        return X_batch, y_batch
    
    def __getitem__(self, index):
        
        batches = self.df[index * self.batch_size:(index + 1) * self.batch_size]
        X, y = self.__get_data(batches)        
        return X, y
    
    def __len__(self):
        return self.n // self.batch_size

# %%
dft = pd.read_csv('dataGencoif8.csv')
dat = []
files = dft["file"]
for i in files:
    if i.split("/")[-2] not in dat:
        dat.append(i.split("/")[-2])

lab = {}

for i in range(84):
    tag = dat[i]
    y_label = np.zeros((84))
    y_label[i] = 1
    lab[tag] = y_label
    
less = 0
good = 0
window_size = 2048
hop_size =256
allLabels = []
sample_rate = 44100

def AttRNNSpeechModel(rnn_func=L.LSTM):
    inputs = Input(shape=(7, 20, 216))
    x = L.Conv2D(128, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(64, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(32, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(16, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(8, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True)
                        )(x)
    x = L.Bidirectional(rnn_func(32, return_sequences=True)
                        )(x)

    xFirst = L.Lambda(lambda q: q[:, -1])(x)
    query = L.Dense(64)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32, activation='relu')(attVector)
    x = L.Dense(16)(x)

    output = L.Dense(84, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

model = AttRNNSpeechModel()#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])
model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.00001) 
dft = shuffle(dft)
training_generator = CustomDataGen(dft, 32, False)
validation_generator = CustomDataGen(dft, 32, True)
mc = ModelCheckpoint('best_modelcoif8.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)

# %%
dft = pd.read_csv('dataGencoif10.csv')
dat = []
files = dft["file"]
for i in files:
    if i.split("/")[-2] not in dat:
        dat.append(i.split("/")[-2])

lab = {}

for i in range(84):
    tag = dat[i]
    y_label = np.zeros((84))
    y_label[i] = 1
    lab[tag] = y_label
    
less = 0
good = 0
window_size = 2048
hop_size =256
allLabels = []
sample_rate = 44100

def AttRNNSpeechModel(rnn_func=L.LSTM):
    inputs = Input(shape=(7, 20, 216))
    x = L.Conv2D(128, (5, 1), activation='relu', padding='same')(inputs)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(64, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(32, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(16, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(8, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)
    x = L.Conv2D(1, (5, 1), activation='relu', padding='same')(x)
    x = L.BatchNormalization()(x)

    x = L.Lambda(lambda q: K.squeeze(q, -1), name='squeeze_last_dim')(x)

    x = L.Bidirectional(rnn_func(64, return_sequences=True)
                        )(x)
    x = L.Bidirectional(rnn_func(32, return_sequences=True)
                        )(x)

    xFirst = L.Lambda(lambda q: q[:, -1])(x)
    query = L.Dense(64)(xFirst)

    # dot product attention
    attScores = L.Dot(axes=[1, 2])([query, x])
    attScores = L.Softmax(name='attSoftmax')(attScores)

    # rescale sequence
    attVector = L.Dot(axes=[1, 1])([attScores, x])

    x = L.Dense(64, activation='relu')(attVector)
    x = L.Dense(32, activation='relu')(attVector)
    x = L.Dense(16)(x)

    output = L.Dense(84, activation='softmax', name='output')(x)

    model = Model(inputs=[inputs], outputs=[output])

    return model

model = AttRNNSpeechModel()#, rnn_func=L.LSTM)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])
model.summary()

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.00001) 
dft = shuffle(dft)
training_generator = CustomDataGen(dft, 32, False)
validation_generator = CustomDataGen(dft, 32, True)
mc = ModelCheckpoint('best_modelcoif10.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
# Out:
# 2021-12-05 01:31:12.652317: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 01:31:12.652692: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 01:31:12.652904: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 01:31:12.653103: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 01:31:12.653322: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 01:31:12.653519: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 01:31:12.653726: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib64:/usr/local/cuda/lib64
# 2021-12-05 01:31:12.653767: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-12-05 01:31:12.654507: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 7, 20, 216)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 7, 20, 128)   138368      ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 7, 20, 128)  512         ['conv2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 7, 20, 64)    41024       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 7, 20, 64)   256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 7, 20, 32)    10272       ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 7, 20, 32)   128         ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_3 (Conv2D)              (None, 7, 20, 16)    2576        ['batch_normalization_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 7, 20, 16)   64          ['conv2d_3[0][0]']
#  rmalization)
#
#  conv2d_4 (Conv2D)              (None, 7, 20, 8)     648         ['batch_normalization_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 7, 20, 8)    32          ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 7, 20, 1)     41          ['batch_normalization_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 20, 1)    4           ['conv2d_5[0][0]']
#  rmalization)
#
#  squeeze_last_dim (Lambda)      (None, 7, 20)        0           ['batch_normalization_5[0][0]']
#
#  bidirectional (Bidirectional)  (None, 7, 128)       43520       ['squeeze_last_dim[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 7, 64)       41216       ['bidirectional[0][0]']
#  )
#
#  lambda (Lambda)                (None, 64)           0           ['bidirectional_1[0][0]']
#
#  dense (Dense)                  (None, 64)           4160        ['lambda[0][0]']
#
#  dot (Dot)                      (None, 7)            0           ['dense[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  attSoftmax (Softmax)           (None, 7)            0           ['dot[0][0]']
#
#  dot_1 (Dot)                    (None, 64)           0           ['attSoftmax[0][0]',
#                                                                   'bidirectional_1[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dot_1[0][0]']
#
#  dense_3 (Dense)                (None, 16)           528         ['dense_2[0][0]']
#
#  output (Dense)                 (None, 84)           1428        ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 286,857
# Trainable params: 286,359
# Non-trainable params: 498
# __________________________________________________________________________________________________
# Epoch 1/50
# /tmp/ipykernel_287661/792062132.py:76: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(generator=training_generator, validation_data = validation_generator, epochs=50, callbacks=[mc,es], use_multiprocessing=True, workers=6)
# 2021-12-05 01:31:18.374121: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2100 num_cores: 64 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 23068672 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 781/781 [==============================] - ETA: 0s - loss: 2.4500 - accuracy: 0.3711
# 2021-12-05 01:32:40.743938: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" vendor: "GenuineIntel" model: "101" frequency: 2100 num_cores: 64 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 32768 l2_cache_size: 1048576 l3_cache_size: 23068672 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# Epoch 00001: val_accuracy improved from -inf to 0.54097, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 99s 119ms/step - loss: 2.4500 - accuracy: 0.3711 - val_loss: 1.6401 - val_accuracy: 0.5410
# Epoch 2/50
# 781/781 [==============================] - ETA: 0s - loss: 0.9635 - accuracy: 0.7077
# Epoch 00002: val_accuracy improved from 0.54097 to 0.70790, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 100s 127ms/step - loss: 0.9635 - accuracy: 0.7077 - val_loss: 0.9098 - val_accuracy: 0.7079
# Epoch 3/50
# 781/781 [==============================] - ETA: 0s - loss: 0.6137 - accuracy: 0.7994
# Epoch 00003: val_accuracy improved from 0.70790 to 0.79663, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 100s 126ms/step - loss: 0.6137 - accuracy: 0.7994 - val_loss: 0.6009 - val_accuracy: 0.7966
# Epoch 4/50
# 781/781 [==============================] - ETA: 0s - loss: 0.4684 - accuracy: 0.8408
# Epoch 00004: val_accuracy improved from 0.79663 to 0.84747, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 101s 127ms/step - loss: 0.4684 - accuracy: 0.8408 - val_loss: 0.4765 - val_accuracy: 0.8475
# Epoch 5/50
# 781/781 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.8672
# Epoch 00005: val_accuracy improved from 0.84747 to 0.85622, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 97s 122ms/step - loss: 0.3834 - accuracy: 0.8672 - val_loss: 0.4285 - val_accuracy: 0.8562
# Epoch 6/50
# 781/781 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8842
# Epoch 00006: val_accuracy improved from 0.85622 to 0.87532, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 102s 129ms/step - loss: 0.3327 - accuracy: 0.8842 - val_loss: 0.3493 - val_accuracy: 0.8753
# Epoch 7/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.8960
# Epoch 00007: val_accuracy improved from 0.87532 to 0.88229, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 404s 516ms/step - loss: 0.2920 - accuracy: 0.8960 - val_loss: 0.3638 - val_accuracy: 0.8823
# Epoch 8/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2615 - accuracy: 0.9068
# Epoch 00008: val_accuracy did not improve from 0.88229
# 781/781 [==============================] - 98s 124ms/step - loss: 0.2615 - accuracy: 0.9068 - val_loss: 0.3599 - val_accuracy: 0.8800
# Epoch 9/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9193
# Epoch 00009: val_accuracy did not improve from 0.88229
# 781/781 [==============================] - 435s 556ms/step - loss: 0.2280 - accuracy: 0.9193 - val_loss: 0.3585 - val_accuracy: 0.8768
# Epoch 10/50
# 781/781 [==============================] - ETA: 0s - loss: 0.2115 - accuracy: 0.9258
# Epoch 00010: val_accuracy improved from 0.88229 to 0.90835, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 101s 127ms/step - loss: 0.2115 - accuracy: 0.9258 - val_loss: 0.2787 - val_accuracy: 0.9084
# Epoch 11/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1891 - accuracy: 0.9329
# Epoch 00011: val_accuracy improved from 0.90835 to 0.91014, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 99s 125ms/step - loss: 0.1891 - accuracy: 0.9329 - val_loss: 0.2875 - val_accuracy: 0.9101
# Epoch 12/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9357
# Epoch 00012: val_accuracy did not improve from 0.91014
# 781/781 [==============================] - 108s 136ms/step - loss: 0.1788 - accuracy: 0.9357 - val_loss: 0.3011 - val_accuracy: 0.9050
# Epoch 13/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9441
# Epoch 00013: val_accuracy did not improve from 0.91014
# 781/781 [==============================] - 99s 125ms/step - loss: 0.1603 - accuracy: 0.9441 - val_loss: 0.4258 - val_accuracy: 0.8721
# Epoch 14/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1642 - accuracy: 0.9421
# Epoch 00014: val_accuracy improved from 0.91014 to 0.91095, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 98s 123ms/step - loss: 0.1642 - accuracy: 0.9421 - val_loss: 0.2854 - val_accuracy: 0.9109
# Epoch 15/50
# 780/781 [============================>.] - ETA: 0s - loss: 0.1356 - accuracy: 0.9534
# Epoch 00015: val_accuracy improved from 0.91095 to 0.91176, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 107s 135ms/step - loss: 0.1359 - accuracy: 0.9533 - val_loss: 0.2889 - val_accuracy: 0.9118
# Epoch 16/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9521
# Epoch 00016: val_accuracy improved from 0.91176 to 0.91985, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 102s 128ms/step - loss: 0.1364 - accuracy: 0.9521 - val_loss: 0.2578 - val_accuracy: 0.9199
# Epoch 17/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9545
# Epoch 00017: val_accuracy did not improve from 0.91985
# 781/781 [==============================] - 97s 122ms/step - loss: 0.1307 - accuracy: 0.9545 - val_loss: 0.3065 - val_accuracy: 0.9051
# Epoch 18/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1203 - accuracy: 0.9581
# Epoch 00018: val_accuracy did not improve from 0.91985
# 781/781 [==============================] - 96s 121ms/step - loss: 0.1203 - accuracy: 0.9581 - val_loss: 0.2605 - val_accuracy: 0.9186
# Epoch 19/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9632
# Epoch 00019: val_accuracy did not improve from 0.91985
# 781/781 [==============================] - 93s 117ms/step - loss: 0.1042 - accuracy: 0.9632 - val_loss: 0.2814 - val_accuracy: 0.9148
# Epoch 20/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.96 - ETA: 0s - loss: 0.1102 - accuracy: 0.9609
# Epoch 00020: val_accuracy improved from 0.91985 to 0.92228, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 94s 118ms/step - loss: 0.1102 - accuracy: 0.9609 - val_loss: 0.2607 - val_accuracy: 0.9223
# Epoch 21/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9652
# Epoch 00021: val_accuracy improved from 0.92228 to 0.92260, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 93s 117ms/step - loss: 0.1003 - accuracy: 0.9652 - val_loss: 0.2787 - val_accuracy: 0.9226
# Epoch 22/50
# 780/781 [============================>.] - ETA: 0s - loss: 0.0846 - accuracy: 0.9713
# Epoch 00022: val_accuracy improved from 0.92260 to 0.93815, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 94s 118ms/step - loss: 0.0845 - accuracy: 0.9713 - val_loss: 0.2182 - val_accuracy: 0.9381
# Epoch 23/50
# 781/781 [==============================] - ETA: 0s - loss: 0.1034 - accuracy: 0.9645
# Epoch 00023: val_accuracy did not improve from 0.93815
# 781/781 [==============================] - 92s 115ms/step - loss: 0.1034 - accuracy: 0.9645 - val_loss: 0.2785 - val_accuracy: 0.9233
# Epoch 24/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0786 - accuracy: 0.9729
# Epoch 00024: val_accuracy did not improve from 0.93815
# 781/781 [==============================] - 95s 119ms/step - loss: 0.0786 - accuracy: 0.9729 - val_loss: 0.2545 - val_accuracy: 0.9279
# Epoch 25/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9690
# Epoch 00025: val_accuracy did not improve from 0.93815
# 781/781 [==============================] - 94s 118ms/step - loss: 0.0898 - accuracy: 0.9690 - val_loss: 0.2893 - val_accuracy: 0.9199
# Epoch 26/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9776
# Epoch 00026: val_accuracy did not improve from 0.93815
# 781/781 [==============================] - 92s 115ms/step - loss: 0.0675 - accuracy: 0.9776 - val_loss: 0.2601 - val_accuracy: 0.9305
# Epoch 27/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0768 - accuracy: 0.9731
# Epoch 00027: val_accuracy did not improve from 0.93815
# 781/781 [==============================] - 93s 117ms/step - loss: 0.0768 - accuracy: 0.9731 - val_loss: 0.2699 - val_accuracy: 0.9262
# Epoch 28/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9750
# Epoch 00028: val_accuracy improved from 0.93815 to 0.94252, saving model to best_modelcoif10.hdf5
# 781/781 [==============================] - 93s 116ms/step - loss: 0.0711 - accuracy: 0.9750 - val_loss: 0.2165 - val_accuracy: 0.9425
# Epoch 29/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9751
# Epoch 00029: val_accuracy did not improve from 0.94252
# 781/781 [==============================] - 91s 115ms/step - loss: 0.0760 - accuracy: 0.9751 - val_loss: 0.2555 - val_accuracy: 0.9292
# Epoch 30/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0708 - accuracy: 0.9754
# Epoch 00030: val_accuracy did not improve from 0.94252
# 781/781 [==============================] - 96s 121ms/step - loss: 0.0708 - accuracy: 0.9754 - val_loss: 0.2313 - val_accuracy: 0.9328
# Epoch 31/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0663 - accuracy: 0.9776
# Epoch 00031: val_accuracy did not improve from 0.94252
# 781/781 [==============================] - 92s 115ms/step - loss: 0.0663 - accuracy: 0.9776 - val_loss: 0.2470 - val_accuracy: 0.9343
# Epoch 32/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9831
# Epoch 00032: val_accuracy did not improve from 0.94252
# 781/781 [==============================] - 92s 115ms/step - loss: 0.0507 - accuracy: 0.9831 - val_loss: 0.2555 - val_accuracy: 0.9385
# Epoch 33/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9792
# Epoch 00033: val_accuracy did not improve from 0.94252
# 781/781 [==============================] - 96s 120ms/step - loss: 0.0613 - accuracy: 0.9792 - val_loss: 0.2324 - val_accuracy: 0.9420
# Epoch 34/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0603 - accuracy: 0.9800
# Epoch 00034: val_accuracy did not improve from 0.94252
# 781/781 [==============================] - 92s 115ms/step - loss: 0.0603 - accuracy: 0.9800 - val_loss: 0.3051 - val_accuracy: 0.9247
# Epoch 35/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9826
# Epoch 00035: val_accuracy did not improve from 0.94252
# 781/781 [==============================] - 94s 117ms/step - loss: 0.0536 - accuracy: 0.9826 - val_loss: 0.2530 - val_accuracy: 0.9346
# Epoch 36/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9813
# Epoch 00036: val_accuracy did not improve from 0.94252
# 781/781 [==============================] - 95s 119ms/step - loss: 0.0545 - accuracy: 0.9813 - val_loss: 0.2374 - val_accuracy: 0.9377
# Epoch 37/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9831
# Epoch 00037: val_accuracy did not improve from 0.94252
# 781/781 [==============================] - 94s 118ms/step - loss: 0.0490 - accuracy: 0.9831 - val_loss: 0.2677 - val_accuracy: 0.9318
# Epoch 38/50
# 781/781 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.9837
# Epoch 00038: val_accuracy did not improve from 0.94252
# 781/781 [==============================] - 93s 117ms/step - loss: 0.0485 - accuracy: 0.9837 - val_loss: 0.2578 - val_accuracy: 0.9373
# Epoch 00038: early stopping
