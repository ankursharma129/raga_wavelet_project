# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

mu = 0
variance = 1
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %%
from scipy.fft import fft

# %%
t = fft(stats.norm.pdf(x, mu, sigma))

# %%
plt.plot(abs(t[:len(t)//2]))

# %%
import numpy
Fs = 8000
f = 5
sample = 8000
x = np.arange(sample)
s = np.sin(2 * np.pi * f * x / Fs)

# %%
plt.plot(s)

# %%
f = fft(s)
f = f[:len(f)//2]

# %%
plt.plot(f)
# Out:
# /opt/conda/lib/python3.9/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
a = stats.norm.pdf(x, mu, sigma)
plt.plot(a*s)

# %%
from scipy.signal import morlet
m = morlet(500, w=5.0, s=1.0, complete=True)

# %%
plt.plot(m)
# Out:
# /opt/conda/lib/python3.9/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
Fs = 8000
f = 200
sample = 8000
x = np.arange(sample)
s = np.sin(2 * np.pi * f * x / Fs)
plt.plot(s[:500])

# %%
sinwave = s[:500]

# %%
mu = 250
variance = 6944
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 500)
gauss = stats.norm.pdf(x, mu, sigma)
plt.plot(x, gauss)
plt.show()

# %%
len(gauss)
# Out:
# 500

# %%
plt.plot(gauss*sinwave)
