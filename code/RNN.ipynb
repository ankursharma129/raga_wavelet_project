# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import scipy
import threading
import python_speech_features
from scipy.io import wavfile
import scipy.fftpack as fft
from scipy.signal import get_window
import IPython.display as ipd
import math
# %matplotlib inline
import librosa
import pickle
from os import listdir
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout
from os.path import isfile, join
workDir = "/Volumes/ANKUR'S/Data for audio/voxcelebDataset"
trainDir = "/Volumes/ANKUR'S/Data for audio/voxcelebDataset/FSDKaggle2018.audio_train"
testDir = "/Volumes/ANKUR'S/Data for audio/voxcelebDataset/FSDKaggle2018.audio_test"

# %%
trainFiles = [f for f in listdir(trainDir) if isfile(join(trainDir, f))]
testFiles = [f for f in listdir(testDir) if isfile(join(testDir, f))]

# %%
print(len(trainFiles))
print(len(testFiles))
# Out:
# 18944
# 3200

# %%
def returnMelCoeff(signal, sr):
    return librosa.feature.mfcc(signal, sr)

# %%
def windowHann(signal, fr, windowSize):
#     print(len(signal), windowSize)
    window = get_window("hann", windowSize)
    windowed = signal * window
    return windowed

# %%
def padSignal(signal, sr, windowSize, hopSize):
    signalLength = len(signal)
    numZeros = windowSize - (signalLength - math.floor(signalLength/hopSize)*hopSize);
    return np.concatenate((signal, np.zeros(numZeros)), axis=None)

# %%
def process(signal, sr, windowSize, hopSize):
    origLength = len(signal)
    signal = padSignal(signal, sr, windowSize, hopSize)
    mfccArray = []
#     print(origLength, len(signal))
    for i in range(0, origLength, hopSize):
        toProcess = windowHann(signal[i: i+windowSize], sr, windowSize)
        mfccs = python_speech_features.mfcc(toProcess, sr, winlen=0.056, nfft = 1235, winstep=0.056)
        mfccArray.append(mfccs[0].tolist())
    return mfccArray

# %%
metaFile = "/Volumes/ANKUR'S/Data for audio/voxcelebDataset/FSDKaggle2018.meta/train_post_competition.csv"
meta = pd.read_csv(metaFile)

# %%
windowSize = 1235
hopSize = 1102
commonData = []
threads = []

for i in trainFiles[:500]:
    fName = os.path.join(trainDir, i)
    signal, sr = librosa.load(fName)
    mfccArray = process(signal, sr, windowSize, hopSize)
    tag = str(meta.loc[meta['fname'] == i]['label']).split()[1]
    a = {tag: mfccArray}
    commonData.append({i:a})
    print("Done with: ", i)
# Out:
# Done with:  00044347.wav
# Done with:  001ca53d.wav
# Done with:  002d256b.wav
# Done with:  0033e230.wav
# Done with:  00353774.wav
# Done with:  003b91e8.wav
# Done with:  003da8e5.wav
# Done with:  0048fd00.wav
# Done with:  004ad66f.wav
# Done with:  0063ab88.wav
# Done with:  006f2f32.wav
# Done with:  0075d39c.wav
# Done with:  00780200.wav
# Done with:  0079d310.wav
# Done with:  0091fc7f.wav
# Done with:  0097160c.wav
# Done with:  00ad7068.wav
# Done with:  00c5808a.wav
# Done with:  00c82919.wav
# Done with:  00c934d7.wav
# Done with:  00c9e799.wav
# Done with:  00cb787c.wav
# Done with:  00ce569f.wav
# Done with:  00d1fe46.wav
# Done with:  00d3bba3.wav
# Done with:  00d40fa2.wav
# Done with:  00d9fa61.wav
# Done with:  00e2b4cd.wav
# Done with:  00f88dc5.wav
# Done with:  00fbb28b.wav
# Done with:  00fcbab2.wav
# Done with:  010aa387.wav
# Done with:  011a2185.wav
# Done with:  0120d246.wav
# Done with:  01235a12.wav
# Done with:  01257aad.wav
# Done with:  01302128.wav
# Done with:  013264d3.wav
# Done with:  013c3135.wav
# Done with:  01506d76.wav
# Done with:  015cf474.wav
# Done with:  0160d55e.wav
# Done with:  01638f61.wav
# Done with:  0172a2a5.wav
# Done with:  017ea24e.wav
# Done with:  01811e48.wav
# Done with:  0184c390.wav
# Done with:  018863f5.wav
# Done with:  018a10bb.wav
# Done with:  018b1df6.wav
# Done with:  018d1dc4.wav
# Done with:  0193042e.wav
# Done with:  01974c7c.wav
# Done with:  019aae9d.wav
# Done with:  019d2a2c.wav
# Done with:  01a36643.wav
# Done with:  01a39e95.wav
# Done with:  01a59a61.wav
# Done with:  01a59c11.wav
# Done with:  01a5dc85.wav
# Done with:  01b9f44a.wav
# Done with:  01c2f88b.wav
# Done with:  01d2475c.wav
# Done with:  01d4dafd.wav
# Done with:  01df7ada.wav
# Done with:  01e723f5.wav
# Done with:  01ec7a01.wav
# Done with:  01ee18fd.wav
# Done with:  01f2e70b.wav
# Done with:  01fc4661.wav
# Done with:  020eb9f6.wav
# Done with:  021f8009.wav
# Done with:  022092bc.wav
# Done with:  02267a1a.wav
# Done with:  02274ee8.wav
# Done with:  022a3507.wav
# Done with:  022cc908.wav
# Done with:  0231b9f3.wav
# Done with:  02328c03.wav
# Done with:  0236dccb.wav
# Done with:  023d3434.wav
# Done with:  0244bb9e.wav
# Done with:  024a193f.wav
# Done with:  024c4c6d.wav
# Done with:  024da466.wav
# Done with:  0256c2f2.wav
# Done with:  0259e5d2.wav
# Done with:  025f3fd2.wav
# Done with:  025f7eac.wav
# Done with:  0262817d.wav
# Done with:  0266774c.wav
# Done with:  027482e2.wav
# Done with:  027aa77c.wav
# Done with:  027aee2a.wav
# Done with:  027cd3fd.wav
# Done with:  0286fc27.wav
# Done with:  029632ad.wav
# Done with:  029b22f3.wav
# Done with:  029ee867.wav
# Done with:  02a3243a.wav
# Done with:  02ac1057.wav
# Done with:  02c095b4.wav
# Done with:  02c9a1f1.wav
# Done with:  02d367e4.wav
# Done with:  02d6b747.wav
# Done with:  02d7fba3.wav
# Done with:  02dbfc78.wav
# Done with:  02e9392e.wav
# Done with:  02eed858.wav
# Done with:  02f8e94d.wav
# Done with:  0313ea1a.wav
# Done with:  032f7280.wav
# Done with:  03320f05.wav
# Done with:  0338f669.wav
# Done with:  034beca1.wav
# Done with:  034e4ffa.wav
# Done with:  0350156b.wav
# Done with:  0356dec7.wav
# Done with:  0356f2ab.wav
# Done with:  03586ad9.wav
# Done with:  03657d6d.wav
# Done with:  03734652.wav
# Done with:  0383c69d.wav
# Done with:  0395ba61.wav
# Done with:  03a01285.wav
# Done with:  03b4aca1.wav
# Done with:  03bb1c33.wav
# Done with:  03bc8fbc.wav
# Done with:  03cd971f.wav
# Done with:  03d00f38.wav
# Done with:  03d42e2e.wav
# Done with:  03e13ae7.wav
# Done with:  03e88255.wav
# Done with:  03e9765d.wav
# Done with:  03ed9ba8.wav
# Done with:  03f38c68.wav
# Done with:  03fc1f96.wav
# Done with:  04076350.wav
# Done with:  04092b14.wav
# Done with:  041396a9.wav
# Done with:  04186a03.wav
# Done with:  04281949.wav
# Done with:  0429828b.wav
# Done with:  04330b10.wav
# Done with:  04335030.wav
# Done with:  043a5393.wav
# Done with:  0446a487.wav
# Done with:  0447d04d.wav
# Done with:  04490642.wav
# Done with:  044be615.wav
# Done with:  0450e72b.wav
# Done with:  04562f7d.wav
# Done with:  0457d8bc.wav
# Done with:  0459f90f.wav
# Done with:  04646cce.wav
# Done with:  047b3d34.wav
# Done with:  047f5b83.wav
# Done with:  0482a372.wav
# Done with:  048fb352.wav
# Done with:  0496718e.wav
# Done with:  04a19a27.wav
# Done with:  04a7003c.wav
# Done with:  04ab05a7.wav
# Done with:  04ad9aa5.wav
# Done with:  04b4009f.wav
# Done with:  04b9a79a.wav
# Done with:  04cce777.wav
# Done with:  04d0cae4.wav
# Done with:  04d33fe7.wav
# Done with:  04e82f46.wav
# Done with:  04e8596a.wav
# Done with:  0508f1e3.wav
# Done with:  051138fc.wav
# Done with:  0513cbfc.wav
# Done with:  05149415.wav
# Done with:  05173c4d.wav
# Done with:  051f9935.wav
# Done with:  0526ac41.wav
# Done with:  052789c8.wav
# Done with:  05309a38.wav
# Done with:  05388f6c.wav
# Done with:  05561612.wav
# Done with:  0556be76.wav
# Done with:  0563ab6e.wav
# Done with:  058b98f0.wav
# Done with:  05a0ca60.wav
# Done with:  05a3154f.wav
# Done with:  05a458a7.wav
# Done with:  05b76c07.wav
# Done with:  05bc162b.wav
# Done with:  05c5ab94.wav
# Done with:  05cc4425.wav
# Done with:  05d0dfa7.wav
# Done with:  05d54a68.wav
# Done with:  05d81cdf.wav
# Done with:  05e4028a.wav
# Done with:  05ecefbe.wav
# Done with:  05ef46ec.wav
# Done with:  05f2c2a6.wav
# Done with:  06006fca.wav
# Done with:  0609bd9e.wav
# Done with:  060b8c30.wav
# Done with:  060ba089.wav
# Done with:  060ca755.wav
# Done with:  060e13d6.wav
# Done with:  060fab76.wav
# Done with:  061cf689.wav
# Done with:  0627acfa.wav
# Done with:  0632d921.wav
# Done with:  0640c787.wav
# Done with:  06487815.wav
# Done with:  064cfad3.wav
# Done with:  065e7bb4.wav
# Done with:  066d40f4.wav
# Done with:  06712325.wav
# Done with:  06730f97.wav
# Done with:  06789937.wav
# Done with:  06896eb5.wav
# Done with:  06959969.wav
# Done with:  06a09fcd.wav
# Done with:  06a1dfc0.wav
# Done with:  06a76756.wav
# Done with:  06b278f7.wav
# Done with:  06b89bf9.wav
# Done with:  06b9dc31.wav
# Done with:  06c1c5c3.wav
# Done with:  06c48eab.wav
# Done with:  06d0d6e4.wav
# Done with:  06d164df.wav
# Done with:  06d2b52b.wav
# Done with:  06dbf664.wav
# Done with:  06dd3b18.wav
# Done with:  06e15d8e.wav
# Done with:  06e87b61.wav
# Done with:  06ed75a7.wav
# Done with:  06f60188.wav
# Done with:  06fbb272.wav
# Done with:  06fd1973.wav
# Done with:  06feb8ea.wav
# Done with:  070183b1.wav
# Done with:  07036b1d.wav
# Done with:  0704ffb8.wav
# Done with:  070bcdd9.wav
# Done with:  070f52cb.wav
# Done with:  0713db9c.wav
# Done with:  0716126b.wav
# Done with:  071803a0.wav
# Done with:  071e836c.wav
# Done with:  071efb95.wav
# Done with:  0720ef3b.wav
# Done with:  07211dfa.wav
# Done with:  072f3031.wav
# Done with:  0730a3d8.wav
# Done with:  0733ce78.wav
# Done with:  0738f99f.wav
# Done with:  0742098b.wav
# Done with:  074cc08b.wav
# Done with:  074e07a5.wav
# Done with:  074e2f09.wav
# Done with:  07563fea.wav
# Done with:  07605b4c.wav
# Done with:  0765b7d1.wav
# Done with:  076b6a7a.wav
# Done with:  07762f74.wav
# Done with:  07764530.wav
# Done with:  0779162e.wav
# Done with:  0784c182.wav
# Done with:  078c67e5.wav
# Done with:  078f7ac0.wav
# Done with:  079968f4.wav
# Done with:  079bb1c3.wav
# Done with:  07a16abd.wav
# Done with:  07a177eb.wav
# Done with:  07a99531.wav
# Done with:  07af4f4d.wav
# Done with:  07b44e8e.wav
# Done with:  07b910ee.wav
# Done with:  07c8c909.wav
# Done with:  07ce4408.wav
# Done with:  07db7f16.wav
# Done with:  07ec6849.wav
# Done with:  07ed1d56.wav
# Done with:  07f16007.wav
# Done with:  07f6b1dc.wav
# Done with:  07f88679.wav
# Done with:  08064f4a.wav
# Done with:  080bffb7.wav
# Done with:  081a3386.wav
# Done with:  081c263d.wav
# Done with:  082321d2.wav
# Done with:  0832c151.wav
# Done with:  085652af.wav
# Done with:  085be86f.wav
# Done with:  086dfaff.wav
# Done with:  086e6a35.wav
# Done with:  0879e568.wav
# Done with:  087f12b6.wav
# Done with:  0886c767.wav
# Done with:  0886d4f8.wav
# Done with:  08893744.wav
# Done with:  08894340.wav
# Done with:  088b75db.wav
# Done with:  088d3f95.wav
# Done with:  08a68ba1.wav
# Done with:  08a94aca.wav
# Done with:  08b54ed0.wav
# Done with:  08b88eb7.wav
# Done with:  08c931f6.wav
# Done with:  08cf2d2b.wav
# Done with:  08d931c3.wav
# Done with:  08dba5f4.wav
# Done with:  08e79547.wav
# Done with:  08fa5140.wav
# Done with:  08fb553f.wav
# Done with:  0906c4a9.wav
# Done with:  090e1d30.wav
# Done with:  090ea106.wav
# Done with:  09158810.wav
# Done with:  0920512f.wav
# Done with:  09282dc5.wav
# Done with:  0933c357.wav
# Done with:  0939d783.wav
# Done with:  093bf325.wav
# Done with:  095138e2.wav
# Done with:  095836cb.wav
# Done with:  0958751e.wav
# Done with:  0969b5c5.wav
# Done with:  096b4d70.wav
# Done with:  097b5ab0.wav
# Done with:  09841f13.wav
# Done with:  098a3205.wav
# Done with:  098c2232.wav
# Done with:  0994e80c.wav
# Done with:  09986ba4.wav
# Done with:  099ce615.wav
# Done with:  09a1cfd7.wav
# Done with:  09a355a9.wav
# Done with:  09a585bf.wav
# Done with:  09a63606.wav
# Done with:  09a732e6.wav
# Done with:  09a7c5ce.wav
# Done with:  09a7dc35.wav
# Done with:  09a895f3.wav
# Done with:  09b51c66.wav
# Done with:  09b8a126.wav
# Done with:  09b901f8.wav
# Done with:  09bc3033.wav
# Done with:  09ca1e09.wav
# Done with:  09ea5276.wav
# Done with:  0a037e96.wav
# Done with:  0a0a8d4c.wav
# Done with:  0a15b36b.wav
# Done with:  0a277f11.wav
# Done with:  0a2a5c05.wav
# Done with:  0a2b4c80.wav
# Done with:  0a32271b.wav
# Done with:  0a366772.wav
# Done with:  0a484e9f.wav
# Done with:  0a49afad.wav
# Done with:  0a54c770.wav
# Done with:  0a6bba04.wav
# Done with:  0a6dbf2c.wav
# Done with:  0a82b4d6.wav
# Done with:  0a8ac55d.wav
# Done with:  0a8d300c.wav
# Done with:  0a925754.wav
# Done with:  0a98104d.wav
# Done with:  0aa17642.wav
# Done with:  0aa32376.wav
# Done with:  0aa7edd0.wav
# Done with:  0aab722d.wav
# Done with:  0aad0a16.wav
# Done with:  0aaed52b.wav
# Done with:  0ac443ad.wav
# Done with:  0ac83c13.wav
# Done with:  0acba147.wav
# Done with:  0ad0bf22.wav
# Done with:  0ad5618e.wav
# Done with:  0ad666e3.wav
# Done with:  0ade0819.wav
# Done with:  0af32053.wav
# Done with:  0afca134.wav
# Done with:  0afcf36b.wav
# Done with:  0aff3cde.wav
# Done with:  0b05208c.wav
# Done with:  0b142b38.wav
# Done with:  0b1f22c3.wav
# Done with:  0b2a3ef0.wav
# Done with:  0b3636e4.wav
# Done with:  0b3c0588.wav
# Done with:  0b3d7a19.wav
# Done with:  0b436682.wav
# Done with:  0b489adc.wav
# Done with:  0b4dc8fc.wav
# Done with:  0b5b6734.wav
# Done with:  0b5dd555.wav
# Done with:  0b5ea11d.wav
# Done with:  0b6ac630.wav
# Done with:  0b6fba96.wav
# Done with:  0b7044b0.wav
# Done with:  0b74f0da.wav
# Done with:  0b7aa40a.wav
# Done with:  0b7f8989.wav
# Done with:  0b80f560.wav
# Done with:  0b82b3a5.wav
# Done with:  0b914d51.wav
# Done with:  0b92a7e0.wav
# Done with:  0b95a1b5.wav
# Done with:  0b9904c1.wav
# Done with:  0ba6976e.wav
# Done with:  0ba8bcc2.wav
# Done with:  0ba927cd.wav
# Done with:  0bab86ae.wav
# Done with:  0bb6b85a.wav
# Done with:  0bc522f3.wav
# Done with:  0bca94ec.wav
# Done with:  0bd9f47b.wav
# Done with:  0bdef4f9.wav
# Done with:  0be0fbaa.wav
# Done with:  0be246ba.wav
# Done with:  0be52cd7.wav
# Done with:  0bf505c1.wav
# Done with:  0bfdf35b.wav
# Done with:  0c080361.wav
# Done with:  0c0f796c.wav
# Done with:  0c118aaa.wav
# Done with:  0c27360a.wav
# Done with:  0c28638b.wav
# Done with:  0c2f1a54.wav
# Done with:  0c3044b3.wav
# Done with:  0c364094.wav
# Done with:  0c36c39a.wav
# Done with:  0c3bdc12.wav
# Done with:  0c3cba8b.wav
# Done with:  0c3e92c7.wav
# Done with:  0c4948ba.wav
# Done with:  0c4f2a87.wav
# Done with:  0c547bc4.wav
# Done with:  0c66ddcb.wav
# Done with:  0c67f402.wav
# Done with:  0c6a3500.wav
# Done with:  0c6ec89a.wav
# Done with:  0c7ae294.wav
# Done with:  0c7eb4eb.wav
# Done with:  0c9abd6a.wav
# Done with:  0ca8b59b.wav
# Done with:  0cafd32f.wav
# Done with:  0cb7fc83.wav
# Done with:  0cbfebc7.wav
# Done with:  0cc4c3b7.wav
# Done with:  0ccf0903.wav
# Done with:  0cdfa126.wav
# Done with:  0ce9b7a0.wav
# Done with:  0cea4550.wav
# Done with:  0cec67d2.wav
# Done with:  0ceed74d.wav
# Done with:  0d0c7375.wav
# Done with:  0d0d1b88.wav
# Done with:  0d0d648b.wav
# Done with:  0d1cb966.wav
# Done with:  0d2047b5.wav
# Done with:  0d30af2b.wav
# Done with:  0d3d36f5.wav
# Done with:  0d481dea.wav
# Done with:  0d649d1b.wav
# Done with:  0d661b19.wav
# Done with:  0d694b51.wav
# Done with:  0d6bb959.wav
# Done with:  0d74110a.wav
# Done with:  0d79765a.wav
# Done with:  0d8012f4.wav
# Done with:  0d804b40.wav
# Done with:  0d9b9a20.wav
# Done with:  0d9f6c10.wav
# Done with:  0da0c554.wav
# Done with:  0da527a6.wav
# Done with:  0da86798.wav
# Done with:  0db954fa.wav
# Done with:  0dbdffe2.wav
# Done with:  0dc26ae9.wav
# Done with:  0dd326ca.wav
# Done with:  0dd54f1f.wav
# Done with:  0ddb4bdf.wav
# Done with:  0de99488.wav
# Done with:  0ded93ce.wav
# Done with:  0dfcedf6.wav
# Done with:  0e19ed55.wav
# Done with:  0e2ec031.wav
# Done with:  0e2fbeb8.wav
# Done with:  0e32c361.wav
# Done with:  0e3aa5cf.wav
# Done with:  0e4372d4.wav
# Done with:  0e439e01.wav
# Done with:  0e451691.wav
# Done with:  0e4583d5.wav
# Done with:  0e51f1d0.wav
# Done with:  0e544eb8.wav
# Done with:  0e5c9ed0.wav
# Done with:  0e5cab29.wav
# Done with:  0e630318.wav

# %%
with open('500dump.pickle', 'wb') as handle:
    pickle.dump(commonData, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('500dump.pickle', 'rb') as handle:
    readData = pickle.load(handle)

# %%
len(readData[0]['00044347.wav']['Hi-hat'])
# Out:
# 281

# %%
maxL = 0
for i in readData:
    for key, value in i.items():
        for j in i[key]:
            if len(i[key][j])>maxL:
                maxL = len(i[key][j])

# %%
maxL
# Out:
# 598

# %%
inputShape = (598, 1)

def buildModel():
    #Initialize RNN:
    regressor = Sequential()

    #Adding the first RNN layer and some Dropout regularization
    regressor.add(SimpleRNN(units = 50, activation='tanh', return_sequences=True, input_shape= inputShape))
    regressor.add(Dropout(0.2))

    #Adding the second RNN layer and some Dropout regularization
    regressor.add(SimpleRNN(units = 50, activation='tanh', return_sequences=True))
    regressor.add(Dropout(0.2))

    #Adding the third RNN layer and some Dropout regularization
    regressor.add(SimpleRNN(units = 50, activation='tanh', return_sequences=True))
    regressor.add(Dropout(0.2))

    #Adding the fourth RNN layer and some Dropout regularization
    regressor.add(SimpleRNN(units = 50))
    regressor.add(Dropout(0.2))

    #Adding the output layer
    regressor.add(Dense(units = 1))

    #Compile the RNN
    regressor.compile(optimizer='adam', loss='mean_squared_error')
    regressor.define()

#Fitting the RNN to the Training set
# regressor.fit(X_train, y_train, epochs=100, batch_size=32)
buildModel()
